# %% [markdown]
# ### Generic queries to display index/mapping

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(hosts = "http://@localhost:9200")

# show documents of an index; increment "size" argument to display more than 100 docs)
result = es.search(index="news", size=100)

# show mapping of an index
#result = es.indices.get_mapping(index="news")

# simple query to mach any filed with any value
query_body = {"query": { "match": { "des_facet": "Content Type: Service"}}}
#result = es.search(index="news", body=query_body)

result.body

# %% [markdown]
# ### News

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(hosts = "http://@localhost:9200")

# Number of documents per sesction
query_body = {
  "size": "0",
  "aggs": {
    "unique_section": {
      "terms": {
        "field": "section",
        "size": 100
      }
    }
  }
}
result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/1038919587.py:15: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 26,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'unique_section': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0,
#    'buckets': [{'key': 'Admin', 'doc_count': 120},
#     {'key': 'Arts', 'doc_count': 120},
#     {'key': 'Automobiles', 'doc_count': 120},
#     {'key': 'Books', 'doc_count': 120},
#     {'key': 'Briefing', 'doc_count': 120},
#     {'key': 'Business', 'doc_count': 120},
#     {'key': 'Climate', 'doc_count': 120},
#     {'key': 'Corrections', 'doc_count': 100},
#     {'key': 'Education', 'doc_count': 100},
#     {'key': 'En español', 'doc_count': 100},
#     {'key': 'Fashion', 'doc_count': 100},
#     {'key': 'Food', 'doc_count': 100},
#     {'key': 'Gameplay', 'doc_count': 100},
#     {'key': 'Health', 'doc_count': 100},
#     {'key': 'Home Page', 'doc_count': 100},
#     {'key': 'Magazine', 'doc_count': 100},
#     {'key': 'Movies', 'doc_count': 100},
#     {'key': 'New York', 'doc_count': 100},
#     {'key': 'Obituaries', 'doc_count': 100},
#     {'key': 'Opinion', 'doc_count': 100},
#     {'key': 'Parenting', 'doc_count': 100},
#     {'key': 'Podcasts', 'doc_count': 100},
#     {'key': 'Reader Center', 'doc_count': 100},
#     {'key': 'Real Estate', 'doc_count': 100},
#     {'key': 'Science', 'doc_count': 100},
#     {'key': 'Smarter Living', 'doc_count': 100},
#     {'key': 'Sports', 'doc_count': 100},
#     {'key': 'Style', 'doc_count': 100},
#     {'key': 'T Brand', 'doc_count': 100},
#     {'key': 'T Magazine', 'doc_count': 100},
#     {'key': 'Technology', 'doc_count': 100},
#     {'key': 'The Learning Network', 'doc_count': 100},
#     {'key': 'The Upshot', 'doc_count': 100},
#     {'key': 'Theater', 'doc_count': 100},
#     {'key': 'Times Insider', 'doc_count': 100},
#     {'key': 'Today’s Paper', 'doc_count': 100},
#     {'key': 'Travel', 'doc_count': 100},
#     {'key': 'U.S.', 'doc_count': 100},
#     {'key': 'Universal', 'doc_count': 100},
#     {'key': 'Well', 'doc_count': 100},
#     {'key': 'World', 'doc_count': 100},
#     {'key': 'Your Money', 'doc_count': 100},
#     {'key': 'Sunday Review', 'doc_count': 90},
#     {'key': 'Video', 'doc_count': 65},
#     {'key': 'Home & Garden', 'doc_count': 55},
#     {'key': 'The Weekly', 'doc_count': 50},
#     {'key': 'Job Market', 'doc_count': 40},
#     {'key': 'Lens', 'doc_count': 25},
#     {'key': 'Guide', 'doc_count': 15}]}}}

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(hosts = "http://@localhost:9200")

# Number of sections in the news index (unique values)
query_body ={
  "size": 0, 
  "aggs": {
    "unique_sections": {
        "cardinality": {
          "field": "section"
        }
    }
  }
}
result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/904639509.py:14: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 8,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'unique_sections': {'value': 49}}}

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(hosts = "http://@localhost:9200")

# number of documents per person mentioned in the article (top 5)
query_body = {
  "size": "0",
  "aggs": {
    "unique_values": {
      "terms": {
        "field": "per_facet",
        "size": 5
      }
    }
  }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/2180218125.py:16: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 8,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'unique_values': {'doc_count_error_upper_bound': 14,
#    'sum_other_doc_count': 2825,
#    'buckets': [{'key': 'Biden, Joseph R Jr', 'doc_count': 98},
#     {'key': 'Putin, Vladimir V', 'doc_count': 92},
#     {'key': 'Trump, Donald J', 'doc_count': 80},
#     {'key': 'Prigozhin, Yevgeny V', 'doc_count': 73},
#     {'key': 'DeSantis, Ron', 'doc_count': 25}]}}}

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(hosts="http://localhost:9200")

# number of documents per location
query_body = {
    "size": 0,
    "aggs": {
        "unique_values": {
            "terms": {
                "field": "geo_facet"
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/835383671.py:17: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 52,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'unique_values': {'doc_count_error_upper_bound': 16,
#    'sum_other_doc_count': 1583,
#    'buckets': [{'key': 'United States', 'doc_count': 163},
#     {'key': 'New York City', 'doc_count': 154},
#     {'key': 'Russia', 'doc_count': 119},
#     {'key': 'Ukraine', 'doc_count': 111},
#     {'key': 'China', 'doc_count': 62},
#     {'key': 'California', 'doc_count': 59},
#     {'key': 'Europe', 'doc_count': 33},
#     {'key': 'India', 'doc_count': 28},
#     {'key': 'Los Angeles (Calif)', 'doc_count': 27},
#     {'key': 'Florida', 'doc_count': 25}]}}}

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(hosts="http://localhost:9200")

# number of documents per article type
query_body = {
    "size": 0,
    "aggs": {
        "unique_values": {
            "terms": {
                "field": "material_type_facet"
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/2265984196.py:16: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 20,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'unique_values': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 157,
#    'buckets': [{'key': 'News', 'doc_count': 3031},
#     {'key': 'Video', 'doc_count': 271},
#     {'key': 'Interactive Feature', 'doc_count': 238},
#     {'key': 'Review', 'doc_count': 210},
#     {'key': 'Slideshow', 'doc_count': 210},
#     {'key': 'Obituary (Obit)', 'doc_count': 161},
#     {'key': 'Op-Ed', 'doc_count': 117},
#     {'key': 'Quote', 'doc_count': 115},
#     {'key': 'briefing', 'doc_count': 104},
#     {'key': 'Live Blog Post', 'doc_count': 66}]}}}

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(hosts="http://localhost:9200")

# number of documents per keyword
query_body = {
    "size": 0,
    "aggs": {
        "unique_values": {
            "terms": {
                "field": "des_facet"
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/705892480.py:16: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 17,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'unique_values': {'doc_count_error_upper_bound': 90,
#    'sum_other_doc_count': 12973,
#    'buckets': [{'key': 'Content Type: Service', 'doc_count': 378},
#     {'key': 'Books and Literature', 'doc_count': 185},
#     {'key': 'United States Politics and Government', 'doc_count': 166},
#     {'key': 'Content Type: Personal Profile', 'doc_count': 159},
#     {'key': 'Global Warming', 'doc_count': 147},
#     {'key': 'Computers and the Internet', 'doc_count': 145},
#     {'key': 'Russian Invasion of Ukraine (2022)', 'doc_count': 145},
#     {'key': 'Real Estate and Housing (Residential)', 'doc_count': 143},
#     {'key': 'Deaths (Obituaries)', 'doc_count': 135},
#     {'key': 'Politics and Government', 'doc_count': 130}]}}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# number of documents per organization
query_body = {
    "size": 0,
    "aggs": {
        "unique_values": {
            "terms": {
                "field": "org_facet"
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/898678341.py:17: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 4,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'unique_values': {'doc_count_error_upper_bound': 17,
#    'sum_other_doc_count': 2300,
#    'buckets': [{'key': 'New York Times', 'doc_count': 101},
#     {'key': 'Wagner Group', 'doc_count': 69},
#     {'key': 'Republican Party', 'doc_count': 66},
#     {'key': 'Hulu.com', 'doc_count': 65},
#     {'key': 'FX (TV Network)', 'doc_count': 62},
#     {'key': 'Supreme Court (US)', 'doc_count': 43},
#     {'key': 'Food and Drug Administration', 'doc_count': 36},
#     {'key': 'Democratic Party', 'doc_count': 32},
#     {'key': 'National Basketball Assn', 'doc_count': 28},
#     {'key': 'OceanGate Expeditions (Argus Expeditions Ltd)',
#      'doc_count': 27}]}}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# articles written by author Jeffrey Gettleman (random author example)
query_body = {
    "query": {
        "match": {
            "byline": {
                "query": "Jeffrey Gettleman",
                "operator": "and"
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/4292393839.py:17: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 176,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 6, 'relation': 'eq'},
#   'max_score': 14.406831,
#   'hits': [{'_index': 'news',
#     '_id': 'eyjX-IgBq0sA4CEluhnw',
#     '_score': 14.406831,
#     '_source': {'slug_name': '26ukraine-briefing-counteroffensive-tracker',
#      'section': 'World',
#      'subsection': 'Europe',
#      'title': 'Tracking Ukraine’s counteroffensive: Here’s the latest on the fighting.',
#      'abstract': '',
#      'uri': 'nyt://article/00596c95-1b23-53cd-bfcd-765c41a2f11d',
#      'url': 'https://www.nytimes.com/live/2023/06/26/world/russia-ukraine-news/tracking-ukraines-counteroffensive-heres-the-latest-on-the-fighting',
#      'byline': 'By Jeffrey Gettleman',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-26T09:40:22-04:00',
#      'created_date': '2023-06-26T09:40:22-04:00',
#      'published_date': '2023-06-26T09:40:22-04:00',
#      'first_published_date': '2023-06-26T09:40:22-04:00',
#      'material_type_facet': 'Live Blog Post',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': [],
#      'org_facet': [],
#      'per_facet': [],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/26ukraine-briefing-counteroffensive-tracker/23ukraine-briefing-carousel-Siversk-630p-zwlh-thumbStandard-v2.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'A Ukrainian soldier atop a military vehicle in Siversk, in eastern Ukraine, on Friday.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/26ukraine-briefing-counteroffensive-tracker/23ukraine-briefing-carousel-Siversk-630p-zwlh-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'A Ukrainian soldier atop a military vehicle in Siversk, in eastern Ukraine, on Friday.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/26ukraine-briefing-counteroffensive-tracker/23ukraine-briefing-carousel-Siversk-630p-zwlh-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'A Ukrainian soldier atop a military vehicle in Siversk, in eastern Ukraine, on Friday.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/26ukraine-briefing-counteroffensive-tracker/23ukraine-briefing-carousel-Siversk-630p-zwlh-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'A Ukrainian soldier atop a military vehicle in Siversk, in eastern Ukraine, on Friday.',
#        'copyright': 'Mauricio Lima for The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'TlA2_ogBugzJx6Btmqj8',
#     '_score': 14.406831,
#     '_source': {'slug_name': '27ukraine-blog-Kherson',
#      'section': 'World',
#      'subsection': 'Europe',
#      'title': 'Ukrainian forces take more swampy river areas near Kherson, Russian analysts say.',
#      'abstract': '',
#      'uri': 'nyt://article/29ab8060-75a9-583c-a9c4-b69595baab6c',
#      'url': 'https://www.nytimes.com/live/2023/06/27/world/russia-ukraine-news/ukrainian-forces-take-more-swampy-river-areas-near-kherson-russian-analysts-say',
#      'byline': 'By Jeffrey Gettleman',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-27T09:22:31-04:00',
#      'created_date': '2023-06-27T09:22:31-04:00',
#      'published_date': '2023-06-27T09:22:31-04:00',
#      'first_published_date': '2023-06-27T09:22:31-04:00',
#      'material_type_facet': 'Live Blog Post',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': [],
#      'org_facet': [],
#      'per_facet': [],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/12/multimedia/27ukraine-blog-Kherson-dngo/12ukraine-ledeall-1-gzvk-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Ukrainian soldiers preparing on Sunday to patrol an area of Kherson, southern Ukraine, that was flooded by the destruction of the Kakhovka dam.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/12/multimedia/27ukraine-blog-Kherson-dngo/12ukraine-ledeall-1-gzvk-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Ukrainian soldiers preparing on Sunday to patrol an area of Kherson, southern Ukraine, that was flooded by the destruction of the Kakhovka dam.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/12/multimedia/27ukraine-blog-Kherson-dngo/12ukraine-ledeall-1-gzvk-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Ukrainian soldiers preparing on Sunday to patrol an area of Kherson, southern Ukraine, that was flooded by the destruction of the Kakhovka dam.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/12/multimedia/27ukraine-blog-Kherson-dngo/12ukraine-ledeall-1-gzvk-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Ukrainian soldiers preparing on Sunday to patrol an area of Kherson, southern Ukraine, that was flooded by the destruction of the Kakhovka dam.',
#        'copyright': 'Mauricio Lima for The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'TVBY_YgBugzJx6BtkZNB',
#     '_score': 14.352598,
#     '_source': {'slug_name': '27ukraine-blog-Kherson',
#      'section': 'World',
#      'subsection': 'Europe',
#      'title': 'Ukrainian forces take more swampy river areas near Kherson, Russian analysts say.',
#      'abstract': '',
#      'uri': 'nyt://article/29ab8060-75a9-583c-a9c4-b69595baab6c',
#      'url': 'https://www.nytimes.com/live/2023/06/27/world/russia-ukraine-news/ukrainian-forces-take-more-swampy-river-areas-near-kherson-russian-analysts-say',
#      'byline': 'By Jeffrey Gettleman',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-27T09:22:31-04:00',
#      'created_date': '2023-06-27T09:22:31-04:00',
#      'published_date': '2023-06-27T09:22:31-04:00',
#      'first_published_date': '2023-06-27T09:22:31-04:00',
#      'material_type_facet': 'Live Blog Post',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': [],
#      'org_facet': [],
#      'per_facet': [],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/12/multimedia/27ukraine-blog-Kherson-dngo/12ukraine-ledeall-1-gzvk-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Ukrainian soldiers preparing on Sunday to patrol an area of Kherson, southern Ukraine, that was flooded by the destruction of the Kakhovka dam.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/12/multimedia/27ukraine-blog-Kherson-dngo/12ukraine-ledeall-1-gzvk-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Ukrainian soldiers preparing on Sunday to patrol an area of Kherson, southern Ukraine, that was flooded by the destruction of the Kakhovka dam.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/12/multimedia/27ukraine-blog-Kherson-dngo/12ukraine-ledeall-1-gzvk-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Ukrainian soldiers preparing on Sunday to patrol an area of Kherson, southern Ukraine, that was flooded by the destruction of the Kakhovka dam.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/12/multimedia/27ukraine-blog-Kherson-dngo/12ukraine-ledeall-1-gzvk-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Ukrainian soldiers preparing on Sunday to patrol an area of Kherson, southern Ukraine, that was flooded by the destruction of the Kakhovka dam.',
#        'copyright': 'Mauricio Lima for The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'RSh_-IgBq0sA4CEl2gRT',
#     '_score': 14.352598,
#     '_source': {'slug_name': '26ukraine-briefing-counteroffensive-tracker',
#      'section': 'World',
#      'subsection': 'Europe',
#      'title': 'Tracking Ukraine’s counteroffensive: Here’s the latest on the fighting.',
#      'abstract': '',
#      'uri': 'nyt://article/00596c95-1b23-53cd-bfcd-765c41a2f11d',
#      'url': 'https://www.nytimes.com/live/2023/06/26/world/russia-ukraine-news/tracking-ukraines-counteroffensive-heres-the-latest-on-the-fighting',
#      'byline': 'By Jeffrey Gettleman',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-26T09:40:22-04:00',
#      'created_date': '2023-06-26T09:40:22-04:00',
#      'published_date': '2023-06-26T09:40:22-04:00',
#      'first_published_date': '2023-06-26T09:40:22-04:00',
#      'material_type_facet': 'Live Blog Post',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': [],
#      'org_facet': [],
#      'per_facet': [],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/26ukraine-briefing-counteroffensive-tracker/23ukraine-briefing-carousel-Siversk-630p-zwlh-thumbStandard-v2.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'A Ukrainian soldier atop a military vehicle in Siversk, in eastern Ukraine, on Friday.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/26ukraine-briefing-counteroffensive-tracker/23ukraine-briefing-carousel-Siversk-630p-zwlh-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'A Ukrainian soldier atop a military vehicle in Siversk, in eastern Ukraine, on Friday.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/26ukraine-briefing-counteroffensive-tracker/23ukraine-briefing-carousel-Siversk-630p-zwlh-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'A Ukrainian soldier atop a military vehicle in Siversk, in eastern Ukraine, on Friday.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/26ukraine-briefing-counteroffensive-tracker/23ukraine-briefing-carousel-Siversk-630p-zwlh-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'A Ukrainian soldier atop a military vehicle in Siversk, in eastern Ukraine, on Friday.',
#        'copyright': 'Mauricio Lima for The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'T1CR_ogBugzJx6BtarVA',
#     '_score': 14.352598,
#     '_source': {'slug_name': '27ukraine-blog-Kherson',
#      'section': 'World',
#      'subsection': 'Europe',
#      'title': 'Ukrainian forces take more swampy river areas near Kherson, Russian analysts say.',
#      'abstract': '',
#      'uri': 'nyt://article/29ab8060-75a9-583c-a9c4-b69595baab6c',
#      'url': 'https://www.nytimes.com/live/2023/06/27/world/russia-ukraine-news/ukrainian-forces-take-more-swampy-river-areas-near-kherson-russian-analysts-say',
#      'byline': 'By Jeffrey Gettleman',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-27T09:22:31-04:00',
#      'created_date': '2023-06-27T09:22:31-04:00',
#      'published_date': '2023-06-27T09:22:31-04:00',
#      'first_published_date': '2023-06-27T09:22:31-04:00',
#      'material_type_facet': 'Live Blog Post',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': [],
#      'org_facet': [],
#      'per_facet': [],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/12/multimedia/27ukraine-blog-Kherson-dngo/12ukraine-ledeall-1-gzvk-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Ukrainian soldiers preparing on Sunday to patrol an area of Kherson, southern Ukraine, that was flooded by the destruction of the Kakhovka dam.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/12/multimedia/27ukraine-blog-Kherson-dngo/12ukraine-ledeall-1-gzvk-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Ukrainian soldiers preparing on Sunday to patrol an area of Kherson, southern Ukraine, that was flooded by the destruction of the Kakhovka dam.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/12/multimedia/27ukraine-blog-Kherson-dngo/12ukraine-ledeall-1-gzvk-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Ukrainian soldiers preparing on Sunday to patrol an area of Kherson, southern Ukraine, that was flooded by the destruction of the Kakhovka dam.',
#        'copyright': 'Mauricio Lima for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/12/multimedia/27ukraine-blog-Kherson-dngo/12ukraine-ledeall-1-gzvk-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Ukrainian soldiers preparing on Sunday to patrol an area of Kherson, southern Ukraine, that was flooded by the destruction of the Kakhovka dam.',
#        'copyright': 'Mauricio Lima for The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'YFBY_YgBugzJx6BtkZNB',
#     '_score': 10.871027,
#     '_source': {'slug_name': '26ukraine-briefing-poland-border',
#      'section': 'World',
#      'subsection': 'Europe',
#      'title': 'Poland and Lithuania raise concerns over border with Belarus after the Wagner founder struck an exile deal.',
#      'abstract': '',
#      'uri': 'nyt://article/107c226d-aacd-5026-a1cc-38658008d049',
#      'url': 'https://www.nytimes.com/live/2023/06/26/world/russia-ukraine-news/poland-and-lithuania-raise-concerns-over-border-with-belarus-after-the-wagner-founder-struck-an-exile-deal',
#      'byline': 'By Jeffrey Gettleman and Ada Petriczko',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-26T17:52:43-04:00',
#      'created_date': '2023-06-26T13:58:18-04:00',
#      'published_date': '2023-06-26T13:58:18-04:00',
#      'first_published_date': '2023-06-26T13:58:18-04:00',
#      'material_type_facet': 'Live Blog Post',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': [],
#      'org_facet': [],
#      'per_facet': [],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/26/multimedia/26ukraine-briefing-poland-border-tmzp/26ukraine-briefing-poland-border-tmzp-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Guards patrolling the Polish-Belarus border near Bialowieza, Poland, in late May.',
#        'copyright': 'Wojtek Radwanski/Agence France-Presse — Getty Images'},
#       {'url': 'https://static01.nyt.com/images/2023/06/26/multimedia/26ukraine-briefing-poland-border-tmzp/26ukraine-briefing-poland-border-tmzp-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Guards patrolling the Polish-Belarus border near Bialowieza, Poland, in late May.',
#        'copyright': 'Wojtek Radwanski/Agence France-Presse — Getty Images'},
#       {'url': 'https://static01.nyt.com/images/2023/06/26/multimedia/26ukraine-briefing-poland-border-tmzp/26ukraine-briefing-poland-border-tmzp-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Guards patrolling the Polish-Belarus border near Bialowieza, Poland, in late May.',
#        'copyright': 'Wojtek Radwanski/Agence France-Presse — Getty Images'},
#       {'url': 'https://static01.nyt.com/images/2023/06/26/multimedia/26ukraine-briefing-poland-border-tmzp/26ukraine-briefing-poland-border-tmzp-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Guards patrolling the Polish-Belarus border near Bialowieza, Poland, in late May.',
#        'copyright': 'Wojtek Radwanski/Agence France-Presse — Getty Images'}]}}]}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# Authors who wrote on Europe, no aggregations
query_body = {
    "_source": ["byline"],
    "query": {
        "multi_match": {
            "query": "Europe",
            "fields": ["geo_facet", "subsection"]
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/3102273603.py:16: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 484,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 113, 'relation': 'eq'},
#   'max_score': 4.6657696,
#   'hits': [{'_index': 'news',
#     '_id': 'RCjO-IgBq0sA4CElvBbR',
#     '_score': 4.6657696,
#     '_source': {'byline': 'By Melissa Eddy'}},
#    {'_index': 'news',
#     '_id': 'gCjP-IgBq0sA4CElVRbX',
#     '_score': 4.6657696,
#     '_source': {'byline': 'By Stanley Reed'}},
#    {'_index': 'news',
#     '_id': '9Ci--IgBq0sA4CElEBWv',
#     '_score': 4.6657696,
#     '_source': {'byline': 'By Stanley Reed'}},
#    {'_index': 'news',
#     '_id': 'sijS-IgBq0sA4CEl7xdD',
#     '_score': 4.6657696,
#     '_source': {'byline': 'By Dylan Loeb McClain'}},
#    {'_index': 'news',
#     '_id': 'RSjU-IgBq0sA4CElVRhS',
#     '_score': 4.6657696,
#     '_source': {'byline': 'By Asher Elbein'}},
#    {'_index': 'news',
#     '_id': 'vyjV-IgBq0sA4CEliBj6',
#     '_score': 4.6657696,
#     '_source': {'byline': 'By Adam Satariano'}},
#    {'_index': 'news',
#     '_id': '9CjT-IgBq0sA4CEliRd8',
#     '_score': 4.6657696,
#     '_source': {'byline': 'By Michael Barbaro, Eric Krupke, Will Reid, Luke Vander Ploeg, Shannon Lin, Rachelle Bonja, Paige Cowett, Mike Benoist, Marion Lozano, Elisheba Ittoop and Chris Wood'}},
#    {'_index': 'news',
#     '_id': 'xFAy_ogBugzJx6BtWqb_',
#     '_score': 4.6657696,
#     '_source': {'byline': 'By Michael Barbaro, Eric Krupke, Will Reid, Luke Vander Ploeg, Shannon Lin, Rachelle Bonja, Paige Cowett, Mike Benoist, Marion Lozano, Elisheba Ittoop and Chris Wood'}},
#    {'_index': 'news',
#     '_id': 'hlBT_YgBugzJx6BtbZFy',
#     '_score': 4.6657696,
#     '_source': {'byline': 'By Dylan Loeb McClain'}},
#    {'_index': 'news',
#     '_id': 'zFBU_YgBugzJx6BtGpGl',
#     '_score': 4.6657696,
#     '_source': {'byline': 'By Michael Barbaro, Eric Krupke, Will Reid, Luke Vander Ploeg, Shannon Lin, Rachelle Bonja, Paige Cowett, Mike Benoist, Marion Lozano, Elisheba Ittoop and Chris Wood'}}]}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# articles mentioning Trump in June 2023
query_body = {
    "query": {
        "bool": {
            "must": [
                {
                    "match": {
                        "per_facet": "Trump, Donald J"
                    }
                }
            ],
            "filter": [
                {
                    "range": {
                        "first_published_date": {
                            "gte": "2023-06-01",
                            "lte": "2023-06-30"
                        }
                    }
                }
            ]
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/2089643583.py:30: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 176,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 58, 'relation': 'eq'},
#   'max_score': 3.7759063,
#   'hits': [{'_index': 'news',
#     '_id': '2SjQ-IgBq0sA4CElIRbn',
#     '_score': 3.7759063,
#     '_source': {'slug_name': '22pol-trump-explainer-esp',
#      'section': 'En español',
#      'subsection': '',
#      'title': '¿Qué pasa si un candidato a la presidencia de EE. UU. es condenado?',
#      'abstract': 'Las leyes estadounidenses y la Constitución brindan respuestas claras solo para algunas dudas que surgen. Otras podrían lanzar al país a territorio desconocido.',
#      'uri': 'nyt://article/ab22341d-af40-56d1-af45-4f0b790804ad',
#      'url': 'https://www.nytimes.com/es/2023/06/22/espanol/trump-investigacion-condena.html',
#      'byline': 'By Maggie Astor',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-22T08:20:42-04:00',
#      'created_date': '2023-06-22T08:20:42-04:00',
#      'published_date': '2023-06-22T08:20:42-04:00',
#      'first_published_date': '2023-06-22T08:20:42-04:00',
#      'material_type_facet': 'News',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': ['Presidential Election of 2024',
#       'United States Politics and Government',
#       'Federal Criminal Case Against Trump (Documents Case)',
#       'New York State Criminal Case Against Trump (71543-23)',
#       'Presidents and Presidency (US)'],
#      'org_facet': ['Justice Department', 'Supreme Court (US)'],
#      'per_facet': ['Trump, Donald J'],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/19/multimedia/00pol-trump-explainer-qmlh-esp/00pol-trump-explainer-qmlh-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'El expresidente Donald Trump ha sido acusado de decenas de delitos en dos casos, uno federal y uno estatal en Nueva York. ',
#        'copyright': 'Doug Mills/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/19/multimedia/00pol-trump-explainer-qmlh-esp/00pol-trump-explainer-qmlh-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'El expresidente Donald Trump ha sido acusado de decenas de delitos en dos casos, uno federal y uno estatal en Nueva York. ',
#        'copyright': 'Doug Mills/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/19/multimedia/00pol-trump-explainer-qmlh-esp/00pol-trump-explainer-qmlh-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'El expresidente Donald Trump ha sido acusado de decenas de delitos en dos casos, uno federal y uno estatal en Nueva York. ',
#        'copyright': 'Doug Mills/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/19/multimedia/00pol-trump-explainer-qmlh-esp/00pol-trump-explainer-qmlh-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'El expresidente Donald Trump ha sido acusado de decenas de delitos en dos casos, uno federal y uno estatal en Nueva York. ',
#        'copyright': 'Doug Mills/The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'qCjS-IgBq0sA4CElvBex',
#     '_score': 3.7759063,
#     '_source': {'slug_name': '23nytoday',
#      'section': 'New York',
#      'subsection': '',
#      'title': 'A Freewheeling 91-Year-Old Principal Retires',
#      'abstract': 'Elaine Schwartz didn’t have an office because she wanted to “hear the kids.” And the cost (to Trump) of Trump’s big mouth.',
#      'uri': 'nyt://article/a267f07d-57cf-563d-878d-c3a2883060c2',
#      'url': 'https://www.nytimes.com/2023/06/23/nyregion/a-freewheeling-91-year-old-principal-retires.html',
#      'byline': 'By James Barron',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-23T03:06:31-04:00',
#      'created_date': '2023-06-23T03:06:31-04:00',
#      'published_date': '2023-06-23T03:06:31-04:00',
#      'first_published_date': '2023-06-23T03:06:31-04:00',
#      'material_type_facet': 'briefing',
#      'kicker': 'New York Today',
#      'subheadline': '',
#      'des_facet': ['Principals (School)',
#       'internal-storyline-no',
#       'Education (K-12)',
#       'Libel and Slander'],
#      'org_facet': ['Education Department (NYC)'],
#      'per_facet': ['Trump, Donald J', 'Carroll, E Jean'],
#      'geo_facet': ['New York City', 'Manhattan (NYC)'],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/23nytoday-principal-mtbh/23nytoday-principal-mtbh-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Michelle V. Agins/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/23nytoday-principal-mtbh/23nytoday-principal-mtbh-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Michelle V. Agins/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/23nytoday-principal-mtbh/23nytoday-principal-mtbh-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Michelle V. Agins/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/23nytoday-principal-mtbh/23nytoday-principal-mtbh-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Michelle V. Agins/The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'PCjW-IgBq0sA4CEl7xmQ',
#     '_score': 3.7759063,
#     '_source': {'slug_name': '21up-trump-mailbag-web',
#      'section': 'The Upshot',
#      'subsection': '',
#      'title': 'Mailbag: Does Trump Represent Half the Country?',
#      'abstract': 'Settling a marital dispute, and a question that gets at a tension within today’s conservatism — in this month’s reader mailbag.',
#      'uri': 'nyt://article/4b7bcfe2-f21c-5b65-806b-938cee06c95c',
#      'url': 'https://www.nytimes.com/2023/06/21/upshot/trump-desantis-conservatives-mailbag.html',
#      'byline': 'By Nate Cohn',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-22T21:07:22-04:00',
#      'created_date': '2023-06-21T05:00:10-04:00',
#      'published_date': '2023-06-21T05:00:10-04:00',
#      'first_published_date': '2023-06-21T05:00:10-04:00',
#      'material_type_facet': 'News',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': ['internal-sub-only-nl',
#       'Presidential Election of 2024',
#       'Elections',
#       'Polls and Public Opinion',
#       'Conservatism (US Politics)',
#       'Liberalism (US Politics)',
#       'United States Politics and Government'],
#      'org_facet': [],
#      'per_facet': ['Trump, Donald J', 'DeSantis, Ron'],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/20/multimedia/20up-trump-love1-mhlp/20up-trump-love1-mhlp-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Mary Altaffer/Associated Press'},
#       {'url': 'https://static01.nyt.com/images/2023/06/20/multimedia/20up-trump-love1-mhlp/20up-trump-love1-mhlp-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Mary Altaffer/Associated Press'},
#       {'url': 'https://static01.nyt.com/images/2023/06/20/multimedia/20up-trump-love1-mhlp/20up-trump-love1-mhlp-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Mary Altaffer/Associated Press'},
#       {'url': 'https://static01.nyt.com/images/2023/06/20/multimedia/20up-trump-love1-mhlp/20up-trump-love1-mhlp-articleInline.jpg',
#        'format': 'Normal',
#        'height': 108,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Mary Altaffer/Associated Press'}]}},
#    {'_index': 'news',
#     '_id': 'RCjW-IgBq0sA4CEl7xmQ',
#     '_score': 3.7759063,
#     '_source': {'slug_name': '07up-gop-candidates-web',
#      'section': 'The Upshot',
#      'subsection': '',
#      'title': 'Do Christie and Pence Make It 2016 Again? Not Yet.',
#      'abstract': 'A bigger field in the G.O.P. primary could chip away at DeSantis’s chances of overtaking Trump.',
#      'uri': 'nyt://article/40ddb609-be98-5bd7-ab8e-88d2fd43d953',
#      'url': 'https://www.nytimes.com/2023/06/07/upshot/christie-pence-republicans-primary.html',
#      'byline': 'By Nate Cohn',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-07T05:00:51-04:00',
#      'created_date': '2023-06-07T05:00:51-04:00',
#      'published_date': '2023-06-07T05:00:51-04:00',
#      'first_published_date': '2023-06-07T05:00:51-04:00',
#      'material_type_facet': 'News',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': ['internal-sub-only-nl',
#       'Presidential Election of 2024',
#       'Primaries and Caucuses',
#       'Presidential Election of 2016',
#       'Polls and Public Opinion',
#       'United States Politics and Government'],
#      'org_facet': [],
#      'per_facet': ['Christie, Christopher J',
#       'Pence, Mike',
#       'Trump, Donald J',
#       'DeSantis, Ron'],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/06/upshot/nate-not-trump-promo-shell-promo/nate-not-trump-promo-shell-promo-thumbStandard.png',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': ''},
#       {'url': 'https://static01.nyt.com/images/2023/06/06/upshot/nate-not-trump-promo-shell-promo/nate-not-trump-promo-shell-promo-mediumThreeByTwo210.png',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': ''},
#       {'url': 'https://static01.nyt.com/images/2023/06/06/upshot/nate-not-trump-promo-shell-promo/nate-not-trump-promo-shell-promo-mediumThreeByTwo440.png',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': ''},
#       {'url': 'https://static01.nyt.com/images/2023/06/06/upshot/nate-not-trump-promo-shell-promo/nate-not-trump-promo-shell-promo-articleInline.png',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': ''}]}},
#    {'_index': 'news',
#     '_id': 'vyjT-IgBq0sA4CElIhes',
#     '_score': 3.7759063,
#     '_source': {'slug_name': '26Lletters',
#      'section': 'Opinion',
#      'subsection': 'Letters',
#      'title': 'Worrying About the Judge and the Jury for Trump’s Trial',
#      'abstract': 'Readers fear that the judge may be biased and the jury intimidated. Also: The revolt in Russia; migrants and New York’s suburbs; climate education.',
#      'uri': 'nyt://article/fd4308fe-21b3-5235-b920-3cf39ec50e6b',
#      'url': 'https://www.nytimes.com/2023/06/26/opinion/letters/trump-trial-judge-jury.html',
#      'byline': '',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-26T12:12:14-04:00',
#      'created_date': '2023-06-26T12:12:14-04:00',
#      'published_date': '2023-06-26T12:12:14-04:00',
#      'first_published_date': '2023-06-26T12:12:14-04:00',
#      'material_type_facet': 'Letter',
#      'kicker': 'letters',
#      'subheadline': '',
#      'des_facet': ['Federal Criminal Case Against Trump (Documents Case)',
#       'Classified Information and State Secrets',
#       'Presidential Election of 2024',
#       'Jury System',
#       'United States Politics and Government',
#       'Suburbs',
#       'Global Warming',
#       'Migrant Labor (Non-Agriculture)',
#       'Education (K-12)'],
#      'org_facet': [],
#      'per_facet': ['Trump, Donald J',
#       'Cannon, Aileen M',
#       'Smith, Jack (Attorney)',
#       'Putin, Vladimir V'],
#      'geo_facet': ['Russia', 'New Jersey'],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25dc-trump-trial-print1-sub/13trump-docs-indictment-blog-democracy-VERSION-hvmq-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'The special counsel, Jack Smith, released an indictment of former President Donald J. Trump this month.',
#        'copyright': 'Kenny Holston/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25dc-trump-trial-print1-sub/13trump-docs-indictment-blog-democracy-VERSION-hvmq-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'The special counsel, Jack Smith, released an indictment of former President Donald J. Trump this month.',
#        'copyright': 'Kenny Holston/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25dc-trump-trial-print1-sub/13trump-docs-indictment-blog-democracy-VERSION-hvmq-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'The special counsel, Jack Smith, released an indictment of former President Donald J. Trump this month.',
#        'copyright': 'Kenny Holston/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25dc-trump-trial-print1-sub/13trump-docs-indictment-blog-democracy-VERSION-hvmq-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'The special counsel, Jack Smith, released an indictment of former President Donald J. Trump this month.',
#        'copyright': 'Kenny Holston/The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'EyjW-IgBq0sA4CEliBkT',
#     '_score': 3.7759063,
#     '_source': {'slug_name': 'republicans-new-hampshire',
#      'section': 'U.S.',
#      'subsection': 'Politics',
#      'title': 'The Republican Field Is Heading to New Hampshire',
#      'abstract': 'Donald Trump, Ron DeSantis and other presidential candidates are traveling to the Granite State this week. ',
#      'uri': 'nyt://interactive/0bafbc35-680a-5c88-9377-83ca3087f846',
#      'url': 'https://www.nytimes.com/interactive/2023/06/26/us/politics/republicans-new-hampshire.html',
#      'byline': 'By Neil Vigdor',
#      'item_type': 'Interactive',
#      'source': 'New York Times',
#      'updated_date': '2023-06-26T11:00:00-04:00',
#      'created_date': '2023-06-26T11:00:00-04:00',
#      'published_date': '2023-06-26T11:00:00-04:00',
#      'first_published_date': '2023-06-26T11:00:00-04:00',
#      'material_type_facet': 'Interactive Feature',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': [],
#      'org_facet': ['Republican Party'],
#      'per_facet': ['DeSantis, Ron', 'Trump, Donald J'],
#      'geo_facet': ['New Hampshire'],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25pol-newhampshire-kbzv/25pol-newhampshire-kbzv-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Sophie Park for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25pol-newhampshire-kbzv/25pol-newhampshire-kbzv-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Sophie Park for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25pol-newhampshire-kbzv/25pol-newhampshire-kbzv-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Sophie Park for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25pol-newhampshire-kbzv/25pol-newhampshire-kbzv-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Sophie Park for The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'GCjW-IgBq0sA4CEliBkT',
#     '_score': 3.7759063,
#     '_source': {'slug_name': '25pol-trump-michigan',
#      'section': 'U.S.',
#      'subsection': 'Politics',
#      'title': 'Trump Campaigns in Michigan, a Battleground That’s Tinted Blue',
#      'abstract': 'With their party out of power, some Republicans in the state are worried that the former president could cost Michigan its status as a swing state.',
#      'uri': 'nyt://article/3138ee62-f5a7-5796-b093-5bcd4f07bf2a',
#      'url': 'https://www.nytimes.com/2023/06/25/us/politics/trump-republicans-michigan.html',
#      'byline': 'By Anjali Huynh',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-25T23:32:27-04:00',
#      'created_date': '2023-06-25T23:32:27-04:00',
#      'published_date': '2023-06-25T23:32:27-04:00',
#      'first_published_date': '2023-06-25T23:32:27-04:00',
#      'material_type_facet': 'News',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': ['Presidential Election of 2024',
#       'United States Politics and Government'],
#      'org_facet': ['Republican Party'],
#      'per_facet': ['Trump, Donald J', 'Karamo, Kristina'],
#      'geo_facet': ['Oakland County (Mich)', 'Michigan'],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25pol-trump-michigan-mcwh/25pol-trump-michigan-mcwh-thumbStandard-v2.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Former President Donald J. Trump’s attacks on liberals and Gov. Ron DeSantis of Florida, a rival for the Republican nomination in 2024, drew the most applause at his speech on Sunday in Michigan.',
#        'copyright': 'Al Goldis/Associated Press'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25pol-trump-michigan-mcwh/25pol-trump-michigan-mcwh-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Former President Donald J. Trump’s attacks on liberals and Gov. Ron DeSantis of Florida, a rival for the Republican nomination in 2024, drew the most applause at his speech on Sunday in Michigan.',
#        'copyright': 'Al Goldis/Associated Press'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25pol-trump-michigan-mcwh/25pol-trump-michigan-mcwh-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Former President Donald J. Trump’s attacks on liberals and Gov. Ron DeSantis of Florida, a rival for the Republican nomination in 2024, drew the most applause at his speech on Sunday in Michigan.',
#        'copyright': 'Al Goldis/Associated Press'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25pol-trump-michigan-mcwh/25pol-trump-michigan-mcwh-articleInline-v2.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Former President Donald J. Trump’s attacks on liberals and Gov. Ron DeSantis of Florida, a rival for the Republican nomination in 2024, drew the most applause at his speech on Sunday in Michigan.',
#        'copyright': 'Al Goldis/Associated Press'}]}},
#    {'_index': 'news',
#     '_id': 'ICjW-IgBq0sA4CEliBkT',
#     '_score': 3.7759063,
#     '_source': {'slug_name': '25pol-trump-money',
#      'section': 'U.S.',
#      'subsection': 'Politics',
#      'title': 'As Legal Fees Mount, Trump Steers Donations Into PAC That Has Covered Them',
#      'abstract': 'A previously unnoticed change in Donald Trump’s online fund-raising appeals allows him to divert a sizable chunk of his 2024 contributions to a group that has spent millions to cover his legal fees.',
#      'uri': 'nyt://article/93e762ea-3c9d-5207-bbeb-7a77c30edf3d',
#      'url': 'https://www.nytimes.com/2023/06/25/us/politics/trump-donations-legal-fees.html',
#      'byline': 'By Shane Goldmacher and Maggie Haberman',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-25T05:00:35-04:00',
#      'created_date': '2023-06-25T05:00:35-04:00',
#      'published_date': '2023-06-25T05:00:35-04:00',
#      'first_published_date': '2023-06-25T05:00:35-04:00',
#      'material_type_facet': 'News',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': ['Presidential Election of 2024',
#       'Campaign Finance',
#       'New York State Criminal Case Against Trump (71543-23)',
#       'Primaries and Caucuses',
#       'Political Action Committees',
#       'Federal Criminal Case Against Trump (Documents Case)',
#       'Legal Profession'],
#      'org_facet': ['Save America PAC'],
#      'per_facet': ['Blanche, Todd (Attorney)', 'Trump, Donald J'],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/24pol-trump-money-mbqj/24pol-trump-money-mbqj-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Former President Donald J. Trump at a campaign stop after his arraignment in Miami in June. Internet archival records show that the split in Mr. Trump’s online campaign contributions changed earlier this year.',
#        'copyright': 'Doug Mills/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/24pol-trump-money-mbqj/24pol-trump-money-mbqj-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Former President Donald J. Trump at a campaign stop after his arraignment in Miami in June. Internet archival records show that the split in Mr. Trump’s online campaign contributions changed earlier this year.',
#        'copyright': 'Doug Mills/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/24pol-trump-money-mbqj/24pol-trump-money-mbqj-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Former President Donald J. Trump at a campaign stop after his arraignment in Miami in June. Internet archival records show that the split in Mr. Trump’s online campaign contributions changed earlier this year.',
#        'copyright': 'Doug Mills/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/24pol-trump-money-mbqj/24pol-trump-money-mbqj-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Former President Donald J. Trump at a campaign stop after his arraignment in Miami in June. Internet archival records show that the split in Mr. Trump’s online campaign contributions changed earlier this year.',
#        'copyright': 'Doug Mills/The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'IijW-IgBq0sA4CEliBkT',
#     '_score': 3.7759063,
#     '_source': {'slug_name': '24POL-TRUMP',
#      'section': 'U.S.',
#      'subsection': 'Politics',
#      'title': 'In Pitch to Evangelicals, Trump Casts Himself as Christian Crusader Who Helped End Roe v. Wade',
#      'abstract': 'Former President Donald J. Trump told an evangelical gathering that no president had done more for Christians than he did.',
#      'uri': 'nyt://article/37b6ae4b-aba2-57dc-89ea-fd0e2202e03f',
#      'url': 'https://www.nytimes.com/2023/06/24/us/politics/trump-abortion-evangelicals.html',
#      'byline': 'By Neil Vigdor',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-25T15:43:09-04:00',
#      'created_date': '2023-06-24T23:55:56-04:00',
#      'published_date': '2023-06-24T23:55:56-04:00',
#      'first_published_date': '2023-06-24T23:55:56-04:00',
#      'material_type_facet': 'News',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': ['Abortion',
#       'Evangelical Movement',
#       'Christians and Christianity',
#       'United States Politics and Government',
#       'Presidential Election of 2024'],
#      'org_facet': ['Republican Party'],
#      'per_facet': ['Trump, Donald J'],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/24-pol-TRUMP-1-qphk/24-pol-TRUMP-1-qphk-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'In an effort to consolidate evangelical support, former President Donald J. Trump emphasized his role in appointing three Supreme Court justices who helped overturn Roe v. Wade.',
#        'copyright': 'Pete Marovich for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/24-pol-TRUMP-1-qphk/24-pol-TRUMP-1-qphk-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'In an effort to consolidate evangelical support, former President Donald J. Trump emphasized his role in appointing three Supreme Court justices who helped overturn Roe v. Wade.',
#        'copyright': 'Pete Marovich for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/24-pol-TRUMP-1-qphk/24-pol-TRUMP-1-qphk-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'In an effort to consolidate evangelical support, former President Donald J. Trump emphasized his role in appointing three Supreme Court justices who helped overturn Roe v. Wade.',
#        'copyright': 'Pete Marovich for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/24-pol-TRUMP-1-qphk/24-pol-TRUMP-1-qphk-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'In an effort to consolidate evangelical support, former President Donald J. Trump emphasized his role in appointing three Supreme Court justices who helped overturn Roe v. Wade.',
#        'copyright': 'Pete Marovich for The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'pCh4-IgBq0sA4CElQgFw',
#     '_score': 3.7759063,
#     '_source': {'slug_name': '22pol-trump-explainer-esp',
#      'section': 'En español',
#      'subsection': '',
#      'title': '¿Qué pasa si un candidato a la presidencia de EE. UU. es condenado?',
#      'abstract': 'Las leyes estadounidenses y la Constitución brindan respuestas claras solo para algunas dudas que surgen. Otras podrían lanzar al país a territorio desconocido.',
#      'uri': 'nyt://article/ab22341d-af40-56d1-af45-4f0b790804ad',
#      'url': 'https://www.nytimes.com/es/2023/06/22/espanol/trump-investigacion-condena.html',
#      'byline': 'By Maggie Astor',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-22T08:20:42-04:00',
#      'created_date': '2023-06-22T08:20:42-04:00',
#      'published_date': '2023-06-22T08:20:42-04:00',
#      'first_published_date': '2023-06-22T08:20:42-04:00',
#      'material_type_facet': 'News',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': ['Presidential Election of 2024',
#       'United States Politics and Government',
#       'Federal Criminal Case Against Trump (Documents Case)',
#       'New York State Criminal Case Against Trump (71543-23)',
#       'Presidents and Presidency (US)'],
#      'org_facet': ['Justice Department', 'Supreme Court (US)'],
#      'per_facet': ['Trump, Donald J'],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/19/multimedia/00pol-trump-explainer-qmlh-esp/00pol-trump-explainer-qmlh-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'El expresidente Donald Trump ha sido acusado de decenas de delitos en dos casos, uno federal y uno estatal en Nueva York. ',
#        'copyright': 'Doug Mills/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/19/multimedia/00pol-trump-explainer-qmlh-esp/00pol-trump-explainer-qmlh-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'El expresidente Donald Trump ha sido acusado de decenas de delitos en dos casos, uno federal y uno estatal en Nueva York. ',
#        'copyright': 'Doug Mills/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/19/multimedia/00pol-trump-explainer-qmlh-esp/00pol-trump-explainer-qmlh-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'El expresidente Donald Trump ha sido acusado de decenas de delitos en dos casos, uno federal y uno estatal en Nueva York. ',
#        'copyright': 'Doug Mills/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/19/multimedia/00pol-trump-explainer-qmlh-esp/00pol-trump-explainer-qmlh-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'El expresidente Donald Trump ha sido acusado de decenas de delitos en dos casos, uno federal y uno estatal en Nueva York. ',
#        'copyright': 'Doug Mills/The New York Times'}]}}]}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# number of articles published per year
query_body = {
    "size": 0,
    "aggs": {
        "articles_over_time": {
            "date_histogram": {
                "field": "first_published_date",
                "calendar_interval": "year"
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/2878854519.py:18: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 24,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'articles_over_time': {'buckets': [{'key_as_string': '1982-01-01T00:00:00.000Z',
#      'key': 378691200000,
#      'doc_count': 5},
#     {'key_as_string': '1983-01-01T00:00:00.000Z',
#      'key': 410227200000,
#      'doc_count': 0},
#     {'key_as_string': '1984-01-01T00:00:00.000Z',
#      'key': 441763200000,
#      'doc_count': 0},
#     {'key_as_string': '1985-01-01T00:00:00.000Z',
#      'key': 473385600000,
#      'doc_count': 0},
#     {'key_as_string': '1986-01-01T00:00:00.000Z',
#      'key': 504921600000,
#      'doc_count': 0},
#     {'key_as_string': '1987-01-01T00:00:00.000Z',
#      'key': 536457600000,
#      'doc_count': 0},
#     {'key_as_string': '1988-01-01T00:00:00.000Z',
#      'key': 567993600000,
#      'doc_count': 0},
#     {'key_as_string': '1989-01-01T00:00:00.000Z',
#      'key': 599616000000,
#      'doc_count': 0},
#     {'key_as_string': '1990-01-01T00:00:00.000Z',
#      'key': 631152000000,
#      'doc_count': 0},
#     {'key_as_string': '1991-01-01T00:00:00.000Z',
#      'key': 662688000000,
#      'doc_count': 0},
#     {'key_as_string': '1992-01-01T00:00:00.000Z',
#      'key': 694224000000,
#      'doc_count': 0},
#     {'key_as_string': '1993-01-01T00:00:00.000Z',
#      'key': 725846400000,
#      'doc_count': 0},
#     {'key_as_string': '1994-01-01T00:00:00.000Z',
#      'key': 757382400000,
#      'doc_count': 0},
#     {'key_as_string': '1995-01-01T00:00:00.000Z',
#      'key': 788918400000,
#      'doc_count': 0},
#     {'key_as_string': '1996-01-01T00:00:00.000Z',
#      'key': 820454400000,
#      'doc_count': 0},
#     {'key_as_string': '1997-01-01T00:00:00.000Z',
#      'key': 852076800000,
#      'doc_count': 0},
#     {'key_as_string': '1998-01-01T00:00:00.000Z',
#      'key': 883612800000,
#      'doc_count': 0},
#     {'key_as_string': '1999-01-01T00:00:00.000Z',
#      'key': 915148800000,
#      'doc_count': 0},
#     {'key_as_string': '2000-01-01T00:00:00.000Z',
#      'key': 946684800000,
#      'doc_count': 0},
#     {'key_as_string': '2001-01-01T00:00:00.000Z',
#      'key': 978307200000,
#      'doc_count': 0},
#     {'key_as_string': '2002-01-01T00:00:00.000Z',
#      'key': 1009843200000,
#      'doc_count': 0},
#     {'key_as_string': '2003-01-01T00:00:00.000Z',
#      'key': 1041379200000,
#      'doc_count': 0},
#     {'key_as_string': '2004-01-01T00:00:00.000Z',
#      'key': 1072915200000,
#      'doc_count': 0},
#     {'key_as_string': '2005-01-01T00:00:00.000Z',
#      'key': 1104537600000,
#      'doc_count': 0},
#     {'key_as_string': '2006-01-01T00:00:00.000Z',
#      'key': 1136073600000,
#      'doc_count': 0},
#     {'key_as_string': '2007-01-01T00:00:00.000Z',
#      'key': 1167609600000,
#      'doc_count': 0},
#     {'key_as_string': '2008-01-01T00:00:00.000Z',
#      'key': 1199145600000,
#      'doc_count': 0},
#     {'key_as_string': '2009-01-01T00:00:00.000Z',
#      'key': 1230768000000,
#      'doc_count': 0},
#     {'key_as_string': '2010-01-01T00:00:00.000Z',
#      'key': 1262304000000,
#      'doc_count': 0},
#     {'key_as_string': '2011-01-01T00:00:00.000Z',
#      'key': 1293840000000,
#      'doc_count': 0},
#     {'key_as_string': '2012-01-01T00:00:00.000Z',
#      'key': 1325376000000,
#      'doc_count': 15},
#     {'key_as_string': '2013-01-01T00:00:00.000Z',
#      'key': 1356998400000,
#      'doc_count': 0},
#     {'key_as_string': '2014-01-01T00:00:00.000Z',
#      'key': 1388534400000,
#      'doc_count': 15},
#     {'key_as_string': '2015-01-01T00:00:00.000Z',
#      'key': 1420070400000,
#      'doc_count': 15},
#     {'key_as_string': '2016-01-01T00:00:00.000Z',
#      'key': 1451606400000,
#      'doc_count': 55},
#     {'key_as_string': '2017-01-01T00:00:00.000Z',
#      'key': 1483228800000,
#      'doc_count': 23},
#     {'key_as_string': '2018-01-01T00:00:00.000Z',
#      'key': 1514764800000,
#      'doc_count': 30},
#     {'key_as_string': '2019-01-01T00:00:00.000Z',
#      'key': 1546300800000,
#      'doc_count': 65},
#     {'key_as_string': '2020-01-01T00:00:00.000Z',
#      'key': 1577836800000,
#      'doc_count': 45},
#     {'key_as_string': '2021-01-01T00:00:00.000Z',
#      'key': 1609459200000,
#      'doc_count': 241},
#     {'key_as_string': '2022-01-01T00:00:00.000Z',
#      'key': 1640995200000,
#      'doc_count': 430},
#     {'key_as_string': '2023-01-01T00:00:00.000Z',
#      'key': 1672531200000,
#      'doc_count': 3741}]}}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# number of articles published per month in 2023
query_body = {
    "size": 0,
    "aggs": {
        "period_based_filter": {
            "filter": {
                "range": {
                    "first_published_date": {
                        "gte": "2023-01-01",
                        "lte": "now"
                    }
                }
            },
            "aggs": {
                "articles_over_time": {
                    "date_histogram": {
                        "field": "first_published_date",
                        "calendar_interval": "month"
                    }
                }
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/967414899.py:30: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 29,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'period_based_filter': {'doc_count': 3741,
#    'articles_over_time': {'buckets': [{'key_as_string': '2023-01-01T00:00:00.000Z',
#       'key': 1672531200000,
#       'doc_count': 41},
#      {'key_as_string': '2023-02-01T00:00:00.000Z',
#       'key': 1675209600000,
#       'doc_count': 20},
#      {'key_as_string': '2023-03-01T00:00:00.000Z',
#       'key': 1677628800000,
#       'doc_count': 187},
#      {'key_as_string': '2023-04-01T00:00:00.000Z',
#       'key': 1680307200000,
#       'doc_count': 115},
#      {'key_as_string': '2023-05-01T00:00:00.000Z',
#       'key': 1682899200000,
#       'doc_count': 198},
#      {'key_as_string': '2023-06-01T00:00:00.000Z',
#       'key': 1685577600000,
#       'doc_count': 3180}]}}}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# number of articles published per month in 2023 per section
query_body = {
    "size": 0,
    "aggs": {
        "period_based_filter": {
            "filter": {
                "range": {
                    "first_published_date": {
                        "gte": "2023-01-01",
                        "lte": "now"
                    }
                }
            },
            "aggs": {
                "articles_over_time": {
                    "date_histogram": {
                        "field": "first_published_date",
                        "calendar_interval": "month"
                    },
                    "aggs": {
                        "unique_section": {
                            "terms": {
                                "field": "section",
                                "size": 500
                            }
                        }
                    }
                }
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/2022915689.py:38: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 143,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'period_based_filter': {'doc_count': 3741,
#    'articles_over_time': {'buckets': [{'key_as_string': '2023-01-01T00:00:00.000Z',
#       'key': 1672531200000,
#       'doc_count': 41,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'T Brand', 'doc_count': 15},
#         {'key': 'Reader Center', 'doc_count': 10},
#         {'key': 'Automobiles', 'doc_count': 6},
#         {'key': 'Lens', 'doc_count': 5},
#         {'key': 'Video', 'doc_count': 5}]}},
#      {'key_as_string': '2023-02-01T00:00:00.000Z',
#       'key': 1675209600000,
#       'doc_count': 20,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Smarter Living', 'doc_count': 10},
#         {'key': 'Video', 'doc_count': 10}]}},
#      {'key_as_string': '2023-03-01T00:00:00.000Z',
#       'key': 1677628800000,
#       'doc_count': 187,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Admin', 'doc_count': 114},
#         {'key': 'Smarter Living', 'doc_count': 25},
#         {'key': 'Education', 'doc_count': 10},
#         {'key': 'Reader Center', 'doc_count': 10},
#         {'key': 'T Brand', 'doc_count': 10},
#         {'key': 'Today’s Paper', 'doc_count': 10},
#         {'key': 'Video', 'doc_count': 5},
#         {'key': 'Obituaries', 'doc_count': 3}]}},
#      {'key_as_string': '2023-04-01T00:00:00.000Z',
#       'key': 1680307200000,
#       'doc_count': 115,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Your Money', 'doc_count': 45},
#         {'key': 'Obituaries', 'doc_count': 35},
#         {'key': 'Smarter Living', 'doc_count': 20},
#         {'key': 'T Brand', 'doc_count': 10},
#         {'key': 'Job Market', 'doc_count': 5}]}},
#      {'key_as_string': '2023-05-01T00:00:00.000Z',
#       'key': 1682899200000,
#       'doc_count': 198,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Your Money', 'doc_count': 35},
#         {'key': 'Fashion', 'doc_count': 30},
#         {'key': 'Obituaries', 'doc_count': 30},
#         {'key': 'T Magazine', 'doc_count': 30},
#         {'key': 'Smarter Living', 'doc_count': 25},
#         {'key': 'Home Page', 'doc_count': 22},
#         {'key': 'Times Insider', 'doc_count': 12},
#         {'key': 'The Upshot', 'doc_count': 8},
#         {'key': 'Admin', 'doc_count': 6}]}},
#      {'key_as_string': '2023-06-01T00:00:00.000Z',
#       'key': 1685577600000,
#       'doc_count': 3180,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Arts', 'doc_count': 120},
#         {'key': 'Books', 'doc_count': 120},
#         {'key': 'Briefing', 'doc_count': 120},
#         {'key': 'Business', 'doc_count': 120},
#         {'key': 'Climate', 'doc_count': 120},
#         {'key': 'Corrections', 'doc_count': 100},
#         {'key': 'En español', 'doc_count': 100},
#         {'key': 'Food', 'doc_count': 100},
#         {'key': 'Gameplay', 'doc_count': 100},
#         {'key': 'Health', 'doc_count': 100},
#         {'key': 'Magazine', 'doc_count': 100},
#         {'key': 'Movies', 'doc_count': 100},
#         {'key': 'New York', 'doc_count': 100},
#         {'key': 'Opinion', 'doc_count': 100},
#         {'key': 'Podcasts', 'doc_count': 100},
#         {'key': 'Real Estate', 'doc_count': 100},
#         {'key': 'Science', 'doc_count': 100},
#         {'key': 'Sports', 'doc_count': 100},
#         {'key': 'Style', 'doc_count': 100},
#         {'key': 'Technology', 'doc_count': 100},
#         {'key': 'The Learning Network', 'doc_count': 100},
#         {'key': 'Theater', 'doc_count': 100},
#         {'key': 'Travel', 'doc_count': 100},
#         {'key': 'U.S.', 'doc_count': 100},
#         {'key': 'Well', 'doc_count': 100},
#         {'key': 'World', 'doc_count': 100},
#         {'key': 'The Upshot', 'doc_count': 92},
#         {'key': 'Times Insider', 'doc_count': 88},
#         {'key': 'Home Page', 'doc_count': 78},
#         {'key': 'Fashion', 'doc_count': 70},
#         {'key': 'T Magazine', 'doc_count': 70},
#         {'key': 'Obituaries', 'doc_count': 32},
#         {'key': 'Smarter Living', 'doc_count': 20},
#         {'key': 'Your Money', 'doc_count': 20},
#         {'key': 'Guide', 'doc_count': 5},
#         {'key': 'T Brand', 'doc_count': 5}]}}]}}}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# number of articles published per day during the month of June
query_body = {
    "size": 0,
    "aggs": {
        "period_based_filter": {
            "filter": {
                "range": {
                    "first_published_date": {
                        "gte": "2023-06-01",
                        "lte": "2023-06-30"
                    }
                }
            },
            "aggs": {
                "articles_over_time": {
                    "date_histogram": {
                        "field": "first_published_date",
                        "calendar_interval": "day"
                    }
                }
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/3769172385.py:30: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 43,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'period_based_filter': {'doc_count': 3180,
#    'articles_over_time': {'buckets': [{'key_as_string': '2023-06-01T00:00:00.000Z',
#       'key': 1685577600000,
#       'doc_count': 45},
#      {'key_as_string': '2023-06-02T00:00:00.000Z',
#       'key': 1685664000000,
#       'doc_count': 5},
#      {'key_as_string': '2023-06-03T00:00:00.000Z',
#       'key': 1685750400000,
#       'doc_count': 10},
#      {'key_as_string': '2023-06-04T00:00:00.000Z',
#       'key': 1685836800000,
#       'doc_count': 15},
#      {'key_as_string': '2023-06-05T00:00:00.000Z',
#       'key': 1685923200000,
#       'doc_count': 10},
#      {'key_as_string': '2023-06-06T00:00:00.000Z',
#       'key': 1686009600000,
#       'doc_count': 5},
#      {'key_as_string': '2023-06-07T00:00:00.000Z',
#       'key': 1686096000000,
#       'doc_count': 25},
#      {'key_as_string': '2023-06-08T00:00:00.000Z',
#       'key': 1686182400000,
#       'doc_count': 25},
#      {'key_as_string': '2023-06-09T00:00:00.000Z',
#       'key': 1686268800000,
#       'doc_count': 33},
#      {'key_as_string': '2023-06-10T00:00:00.000Z',
#       'key': 1686355200000,
#       'doc_count': 20},
#      {'key_as_string': '2023-06-11T00:00:00.000Z',
#       'key': 1686441600000,
#       'doc_count': 10},
#      {'key_as_string': '2023-06-12T00:00:00.000Z',
#       'key': 1686528000000,
#       'doc_count': 12},
#      {'key_as_string': '2023-06-13T00:00:00.000Z',
#       'key': 1686614400000,
#       'doc_count': 7},
#      {'key_as_string': '2023-06-14T00:00:00.000Z',
#       'key': 1686700800000,
#       'doc_count': 68},
#      {'key_as_string': '2023-06-15T00:00:00.000Z',
#       'key': 1686787200000,
#       'doc_count': 135},
#      {'key_as_string': '2023-06-16T00:00:00.000Z',
#       'key': 1686873600000,
#       'doc_count': 84},
#      {'key_as_string': '2023-06-17T00:00:00.000Z',
#       'key': 1686960000000,
#       'doc_count': 66},
#      {'key_as_string': '2023-06-18T00:00:00.000Z',
#       'key': 1687046400000,
#       'doc_count': 52},
#      {'key_as_string': '2023-06-19T00:00:00.000Z',
#       'key': 1687132800000,
#       'doc_count': 107},
#      {'key_as_string': '2023-06-20T00:00:00.000Z',
#       'key': 1687219200000,
#       'doc_count': 125},
#      {'key_as_string': '2023-06-21T00:00:00.000Z',
#       'key': 1687305600000,
#       'doc_count': 182},
#      {'key_as_string': '2023-06-22T00:00:00.000Z',
#       'key': 1687392000000,
#       'doc_count': 309},
#      {'key_as_string': '2023-06-23T00:00:00.000Z',
#       'key': 1687478400000,
#       'doc_count': 490},
#      {'key_as_string': '2023-06-24T00:00:00.000Z',
#       'key': 1687564800000,
#       'doc_count': 212},
#      {'key_as_string': '2023-06-25T00:00:00.000Z',
#       'key': 1687651200000,
#       'doc_count': 246},
#      {'key_as_string': '2023-06-26T00:00:00.000Z',
#       'key': 1687737600000,
#       'doc_count': 521},
#      {'key_as_string': '2023-06-27T00:00:00.000Z',
#       'key': 1687824000000,
#       'doc_count': 361}]}}}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# number of mentions of persons (top 5) per day during the month of June 2023
query_body = {
    "size": 0,
    "aggs": {
        "period_based_filter": {
            "filter": {
                "range": {
                    "first_published_date": {
                        "gte": "2023-06-01",
                        "lte": "2023-06-30"
                    }
                }
            },
            "aggs": {
                "articles_over_time": {
                    "date_histogram": {
                        "field": "first_published_date",
                        "calendar_interval": "day"
                    },
                    "aggs": {
                        "unique_person": {
                            "terms": {
                                "field": "per_facet",
                                "size": 5
                            }
                        }
                    }
                }
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/1936158739.py:38: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 79,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'period_based_filter': {'doc_count': 3180,
#    'articles_over_time': {'buckets': [{'key_as_string': '2023-06-01T00:00:00.000Z',
#       'key': 1685577600000,
#       'doc_count': 45,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Biden, Joseph R Jr', 'doc_count': 5},
#         {'key': 'McCarthy, Kevin (1965- )', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-02T00:00:00.000Z',
#       'key': 1685664000000,
#       'doc_count': 5,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': []}},
#      {'key_as_string': '2023-06-03T00:00:00.000Z',
#       'key': 1685750400000,
#       'doc_count': 10,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': []}},
#      {'key_as_string': '2023-06-04T00:00:00.000Z',
#       'key': 1685836800000,
#       'doc_count': 15,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Simonischek, Peter', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-05T00:00:00.000Z',
#       'key': 1685923200000,
#       'doc_count': 10,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': []}},
#      {'key_as_string': '2023-06-06T00:00:00.000Z',
#       'key': 1686009600000,
#       'doc_count': 5,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'McCarthy, Kevin (1965- )', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-07T00:00:00.000Z',
#       'key': 1686096000000,
#       'doc_count': 25,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 5,
#        'buckets': [{'key': 'Christie, Christopher J', 'doc_count': 5},
#         {'key': 'DeSantis, Ron', 'doc_count': 5},
#         {'key': 'Lowe, Rick', 'doc_count': 5},
#         {'key': 'Museveni, Yoweri', 'doc_count': 5},
#         {'key': 'Pence, Mike', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-08T00:00:00.000Z',
#       'key': 1686182400000,
#       'doc_count': 25,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Adams, Eric L', 'doc_count': 5},
#         {'key': 'Tisch, Jessica (1981- )', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-09T00:00:00.000Z',
#       'key': 1686268800000,
#       'doc_count': 33,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Sullivan, Lou (1951-91)', 'doc_count': 5},
#         {'key': 'zur Hausen, Harald', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-10T00:00:00.000Z',
#       'key': 1686355200000,
#       'doc_count': 20,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': []}},
#      {'key_as_string': '2023-06-11T00:00:00.000Z',
#       'key': 1686441600000,
#       'doc_count': 10,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': []}},
#      {'key_as_string': '2023-06-12T00:00:00.000Z',
#       'key': 1686528000000,
#       'doc_count': 12,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': []}},
#      {'key_as_string': '2023-06-13T00:00:00.000Z',
#       'key': 1686614400000,
#       'doc_count': 7,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': []}},
#      {'key_as_string': '2023-06-14T00:00:00.000Z',
#       'key': 1686700800000,
#       'doc_count': 68,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 5,
#        'buckets': [{'key': 'Biden, Joseph R Jr', 'doc_count': 5},
#         {'key': 'Musk, Elon', 'doc_count': 5},
#         {'key': 'Trump, Donald J', 'doc_count': 5},
#         {'key': 'Manchin, Joe III', 'doc_count': 4},
#         {'key': 'McMorris Rodgers, Cathy', 'doc_count': 4}]}},
#      {'key_as_string': '2023-06-15T00:00:00.000Z',
#       'key': 1686787200000,
#       'doc_count': 135,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 40,
#        'buckets': [{'key': 'Biden, Joseph R Jr', 'doc_count': 6},
#         {'key': 'Bamford, George (Watchmaker)', 'doc_count': 5},
#         {'key': 'Barbasini, Enrico', 'doc_count': 5},
#         {'key': 'CAConrad (1966- )', 'doc_count': 5},
#         {'key': 'Deschoux, Marc Andre', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-16T00:00:00.000Z',
#       'key': 1686873600000,
#       'doc_count': 84,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Carberry, Colin', 'doc_count': 2},
#         {'key': 'Frecknall, Rebecca', 'doc_count': 2},
#         {'key': 'Jimoh, Toheeb (1997- )', 'doc_count': 2},
#         {'key': 'Patterson, Glenn (1961- )', 'doc_count': 2},
#         {'key': 'Shakespeare, William', 'doc_count': 2}]}},
#      {'key_as_string': '2023-06-17T00:00:00.000Z',
#       'key': 1686960000000,
#       'doc_count': 66,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Moore, Lorrie', 'doc_count': 5},
#         {'key': 'Murthy, Vivek H', 'doc_count': 5},
#         {'key': 'Zhao, Changpeng', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-18T00:00:00.000Z',
#       'key': 1687046400000,
#       'doc_count': 52,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 6,
#        'buckets': [{'key': 'Irby, Samantha', 'doc_count': 5},
#         {'key': 'Kanner, Leo', 'doc_count': 5},
#         {'key': 'Triplett, Donald (1933-2023)', 'doc_count': 5},
#         {'key': 'Huertas, Justin (Playwright)', 'doc_count': 4},
#         {'key': 'Ivie, Brandon', 'doc_count': 4}]}},
#      {'key_as_string': '2023-06-19T00:00:00.000Z',
#       'key': 1687132800000,
#       'doc_count': 107,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 15,
#        'buckets': [{'key': 'Fitzgerald, F Scott', 'doc_count': 5},
#         {'key': 'Jerome, Jharrel (1997- )', 'doc_count': 5},
#         {'key': 'Jordan, Jim (1964- )', 'doc_count': 5},
#         {'key': 'Riley, Boots', 'doc_count': 5},
#         {'key': 'Sheffer, Edith', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-20T00:00:00.000Z',
#       'key': 1687219200000,
#       'doc_count': 125,
#       'unique_person': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 32,
#        'buckets': [{'key': 'Dutta, Ritwick', 'doc_count': 6},
#         {'key': 'Cuiffo, Steve', 'doc_count': 5},
#         {'key': 'Ebb, Fred', 'doc_count': 5},
#         {'key': 'Grusch, David', 'doc_count': 5},
#         {'key': 'Hnath, Lucas', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-21T00:00:00.000Z',
#       'key': 1687305600000,
#       'doc_count': 182,
#       'unique_person': {'doc_count_error_upper_bound': 4,
#        'sum_other_doc_count': 95,
#        'buckets': [{'key': 'Biden, Joseph R Jr', 'doc_count': 12},
#         {'key': 'Modi, Narendra', 'doc_count': 6},
#         {'key': 'Biden, Hunter', 'doc_count': 5},
#         {'key': 'Carberry, Colin', 'doc_count': 5},
#         {'key': 'DeSantis, Ron', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-22T00:00:00.000Z',
#       'key': 1687392000000,
#       'doc_count': 309,
#       'unique_person': {'doc_count_error_upper_bound': 8,
#        'sum_other_doc_count': 322,
#        'buckets': [{'key': 'Biden, Joseph R Jr', 'doc_count': 16},
#         {'key': 'Modi, Narendra', 'doc_count': 8},
#         {'key': 'Baldwin, James (1924-87)', 'doc_count': 5},
#         {'key': 'Bechdel, Alison', 'doc_count': 5},
#         {'key': 'Binnie, Imogen', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-23T00:00:00.000Z',
#       'key': 1687478400000,
#       'doc_count': 490,
#       'unique_person': {'doc_count_error_upper_bound': 7,
#        'sum_other_doc_count': 390,
#        'buckets': [{'key': 'Biden, Joseph R Jr', 'doc_count': 16},
#         {'key': 'Bock, Jerry', 'doc_count': 10},
#         {'key': 'Brace, Adam', 'doc_count': 10},
#         {'key': 'Harnick, Sheldon', 'doc_count': 10},
#         {'key': 'Miller, Ezra', 'doc_count': 10}]}},
#      {'key_as_string': '2023-06-24T00:00:00.000Z',
#       'key': 1687564800000,
#       'doc_count': 212,
#       'unique_person': {'doc_count_error_upper_bound': 4,
#        'sum_other_doc_count': 117,
#        'buckets': [{'key': 'Prigozhin, Yevgeny V', 'doc_count': 13},
#         {'key': 'Putin, Vladimir V', 'doc_count': 13},
#         {'key': 'Breitwieser, Stephane', 'doc_count': 6},
#         {'key': 'Brodeur, Adrienne', 'doc_count': 6},
#         {'key': 'Finkel, Michael', 'doc_count': 6}]}},
#      {'key_as_string': '2023-06-25T00:00:00.000Z',
#       'key': 1687651200000,
#       'doc_count': 246,
#       'unique_person': {'doc_count_error_upper_bound': 6,
#        'sum_other_doc_count': 177,
#        'buckets': [{'key': 'Prigozhin, Yevgeny V', 'doc_count': 13},
#         {'key': 'Putin, Vladimir V', 'doc_count': 13},
#         {'key': 'Trump, Donald J', 'doc_count': 7},
#         {'key': 'Burton, Tara Isabella', 'doc_count': 6},
#         {'key': 'Douglass, Frederick', 'doc_count': 6}]}},
#      {'key_as_string': '2023-06-26T00:00:00.000Z',
#       'key': 1687737600000,
#       'doc_count': 521,
#       'unique_person': {'doc_count_error_upper_bound': 8,
#        'sum_other_doc_count': 504,
#        'buckets': [{'key': 'Putin, Vladimir V', 'doc_count': 49},
#         {'key': 'Prigozhin, Yevgeny V', 'doc_count': 32},
#         {'key': 'Biden, Joseph R Jr', 'doc_count': 15},
#         {'key': 'Jackson, Shirley', 'doc_count': 11},
#         {'key': 'Adams, Eric L', 'doc_count': 8}]}},
#      {'key_as_string': '2023-06-27T00:00:00.000Z',
#       'key': 1687824000000,
#       'doc_count': 361,
#       'unique_person': {'doc_count_error_upper_bound': 5,
#        'sum_other_doc_count': 305,
#        'buckets': [{'key': 'Putin, Vladimir V', 'doc_count': 17},
#         {'key': 'Prigozhin, Yevgeny V', 'doc_count': 15},
#         {'key': 'Trump, Donald J', 'doc_count': 15},
#         {'key': 'DeSantis, Ron', 'doc_count': 11},
#         {'key': 'Biden, Joseph R Jr', 'doc_count': 9}]}}]}}}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# number of mentions of organizations (top 5) per week during the month of June 2023
query_body = {
    "size": 0,
    "aggs": {
        "period_based_filter": {
            "filter": {
                "range": {
                    "first_published_date": {
                        "gte": "2023-06-01",
                        "lte": "2023-06-30"
                    }
                }
            },
            "aggs": {
                "articles_over_time": {
                    "date_histogram": {
                        "field": "first_published_date",
                        "calendar_interval": "week"
                    },
                    "aggs": {
                        "unique_organization": {
                            "terms": {
                                "field": "org_facet",
                                "size": 5
                            }
                        }
                    }
                }
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/461573010.py:38: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 50,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'period_based_filter': {'doc_count': 3180,
#    'articles_over_time': {'buckets': [{'key_as_string': '2023-05-29T00:00:00.000Z',
#       'key': 1685318400000,
#       'doc_count': 75,
#       'unique_organization': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Burgtheater (Vienna, Austria)', 'doc_count': 5},
#         {'key': 'Democratic Party', 'doc_count': 5},
#         {'key': 'Republican Party', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-05T00:00:00.000Z',
#       'key': 1685923200000,
#       'doc_count': 128,
#       'unique_organization': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 41,
#        'buckets': [{'key': 'Astier de Villatte', 'doc_count': 5},
#         {'key': 'Cash App (Mobile App)', 'doc_count': 5},
#         {'key': 'Consumer Financial Protection Bureau', 'doc_count': 5},
#         {'key': 'DS & Durga LLC', 'doc_count': 5},
#         {'key': 'Estee Lauder Companies Inc', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-12T00:00:00.000Z',
#       'key': 1686528000000,
#       'doc_count': 424,
#       'unique_organization': {'doc_count_error_upper_bound': 6,
#        'sum_other_doc_count': 276,
#        'buckets': [{'key': 'Alphabet Inc', 'doc_count': 10},
#         {'key': 'European Union', 'doc_count': 10},
#         {'key': 'Google Inc', 'doc_count': 10},
#         {'key': 'Parmigiani Fleurier SA', 'doc_count': 7},
#         {'key': 'Atlantic, The (Magazine)', 'doc_count': 4}]}},
#      {'key_as_string': '2023-06-19T00:00:00.000Z',
#       'key': 1687132800000,
#       'doc_count': 1671,
#       'unique_organization': {'doc_count_error_upper_bound': 9,
#        'sum_other_doc_count': 706,
#        'buckets': [{'key': 'National Basketball Assn', 'doc_count': 27},
#         {'key': 'OceanGate Expeditions (Argus Expeditions Ltd)',
#          'doc_count': 24},
#         {'key': 'Wagner Group', 'doc_count': 18},
#         {'key': 'Republican Party', 'doc_count': 17},
#         {'key': 'Food and Drug Administration', 'doc_count': 15}]}},
#      {'key_as_string': '2023-06-26T00:00:00.000Z',
#       'key': 1687737600000,
#       'doc_count': 882,
#       'unique_organization': {'doc_count_error_upper_bound': 8,
#        'sum_other_doc_count': 666,
#        'buckets': [{'key': 'Wagner Group', 'doc_count': 51},
#         {'key': 'Republican Party', 'doc_count': 27},
#         {'key': 'Supreme Court (US)', 'doc_count': 24},
#         {'key': 'Democratic Party', 'doc_count': 15},
#         {'key': 'Food and Drug Administration', 'doc_count': 11}]}}]}}}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# number of articles published per day during the month of June 2023 per section
query_body = {
    "size": 0,
    "aggs": {
        "period_based_filter": {
            "filter": {
                "range": {
                    "first_published_date": {
                        "gte": "2023-06-01",
                        "lte": "2023-06-30"
                    }
                }
            },
            "aggs": {
                "articles_over_time": {
                    "date_histogram": {
                        "field": "first_published_date",
                        "calendar_interval": "day"
                    },
                    "aggs": {
                        "unique_section": {
                            "terms": {
                                "field": "section",
                                "size": 500
                            }
                        }
                    }
                }
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/1089224315.py:38: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 28,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'period_based_filter': {'doc_count': 3180,
#    'articles_over_time': {'buckets': [{'key_as_string': '2023-06-01T00:00:00.000Z',
#       'key': 1685577600000,
#       'doc_count': 45,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Home Page', 'doc_count': 10},
#         {'key': 'T Magazine', 'doc_count': 10},
#         {'key': 'The Upshot', 'doc_count': 10},
#         {'key': 'Guide', 'doc_count': 5},
#         {'key': 'T Brand', 'doc_count': 5},
#         {'key': 'Your Money', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-02T00:00:00.000Z',
#       'key': 1685664000000,
#       'doc_count': 5,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Smarter Living', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-03T00:00:00.000Z',
#       'key': 1685750400000,
#       'doc_count': 10,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'The Upshot', 'doc_count': 10}]}},
#      {'key_as_string': '2023-06-04T00:00:00.000Z',
#       'key': 1685836800000,
#       'doc_count': 15,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Times Insider', 'doc_count': 10},
#         {'key': 'Obituaries', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-05T00:00:00.000Z',
#       'key': 1685923200000,
#       'doc_count': 10,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'T Magazine', 'doc_count': 5},
#         {'key': 'The Upshot', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-06T00:00:00.000Z',
#       'key': 1686009600000,
#       'doc_count': 5,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Times Insider', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-07T00:00:00.000Z',
#       'key': 1686096000000,
#       'doc_count': 25,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Fashion', 'doc_count': 5},
#         {'key': 'Home Page', 'doc_count': 5},
#         {'key': 'T Magazine', 'doc_count': 5},
#         {'key': 'The Upshot', 'doc_count': 5},
#         {'key': 'Times Insider', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-08T00:00:00.000Z',
#       'key': 1686182400000,
#       'doc_count': 25,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Home Page', 'doc_count': 10},
#         {'key': 'T Magazine', 'doc_count': 5},
#         {'key': 'The Upshot', 'doc_count': 5},
#         {'key': 'Times Insider', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-09T00:00:00.000Z',
#       'key': 1686268800000,
#       'doc_count': 33,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Health', 'doc_count': 13},
#         {'key': 'Obituaries', 'doc_count': 5},
#         {'key': 'Smarter Living', 'doc_count': 5},
#         {'key': 'Times Insider', 'doc_count': 5},
#         {'key': 'Your Money', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-10T00:00:00.000Z',
#       'key': 1686355200000,
#       'doc_count': 20,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'The Upshot', 'doc_count': 10},
#         {'key': 'Fashion', 'doc_count': 5},
#         {'key': 'Health', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-11T00:00:00.000Z',
#       'key': 1686441600000,
#       'doc_count': 10,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Times Insider', 'doc_count': 10}]}},
#      {'key_as_string': '2023-06-12T00:00:00.000Z',
#       'key': 1686528000000,
#       'doc_count': 12,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Fashion', 'doc_count': 5},
#         {'key': 'Health', 'doc_count': 5},
#         {'key': 'Well', 'doc_count': 2}]}},
#      {'key_as_string': '2023-06-13T00:00:00.000Z',
#       'key': 1686614400000,
#       'doc_count': 7,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Health', 'doc_count': 5},
#         {'key': 'Well', 'doc_count': 2}]}},
#      {'key_as_string': '2023-06-14T00:00:00.000Z',
#       'key': 1686700800000,
#       'doc_count': 68,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Technology', 'doc_count': 21},
#         {'key': 'Climate', 'doc_count': 7},
#         {'key': 'Well', 'doc_count': 7},
#         {'key': 'Magazine', 'doc_count': 6},
#         {'key': 'Health', 'doc_count': 5},
#         {'key': 'Home Page', 'doc_count': 5},
#         {'key': 'The Upshot', 'doc_count': 5},
#         {'key': 'Times Insider', 'doc_count': 5},
#         {'key': 'Your Money', 'doc_count': 5},
#         {'key': 'The Learning Network', 'doc_count': 2}]}},
#      {'key_as_string': '2023-06-15T00:00:00.000Z',
#       'key': 1686787200000,
#       'doc_count': 135,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Fashion', 'doc_count': 45},
#         {'key': 'Climate', 'doc_count': 18},
#         {'key': 'Health', 'doc_count': 15},
#         {'key': 'Magazine', 'doc_count': 15},
#         {'key': 'Science', 'doc_count': 10},
#         {'key': 'T Magazine', 'doc_count': 10},
#         {'key': 'Well', 'doc_count': 10},
#         {'key': 'Technology', 'doc_count': 5},
#         {'key': 'Times Insider', 'doc_count': 5},
#         {'key': 'The Learning Network', 'doc_count': 2}]}},
#      {'key_as_string': '2023-06-16T00:00:00.000Z',
#       'key': 1686873600000,
#       'doc_count': 84,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Home Page', 'doc_count': 10},
#         {'key': 'Technology', 'doc_count': 10},
#         {'key': 'The Learning Network', 'doc_count': 10},
#         {'key': 'Climate', 'doc_count': 6},
#         {'key': 'Food', 'doc_count': 5},
#         {'key': 'Health', 'doc_count': 5},
#         {'key': 'Magazine', 'doc_count': 5},
#         {'key': 'Science', 'doc_count': 5},
#         {'key': 'Smarter Living', 'doc_count': 5},
#         {'key': 'T Magazine', 'doc_count': 5},
#         {'key': 'Well', 'doc_count': 5},
#         {'key': 'Your Money', 'doc_count': 5},
#         {'key': 'Corrections', 'doc_count': 4},
#         {'key': 'Theater', 'doc_count': 4}]}},
#      {'key_as_string': '2023-06-17T00:00:00.000Z',
#       'key': 1686960000000,
#       'doc_count': 66,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'The Upshot', 'doc_count': 15},
#         {'key': 'Well', 'doc_count': 10},
#         {'key': 'Corrections', 'doc_count': 7},
#         {'key': 'Climate', 'doc_count': 6},
#         {'key': 'Real Estate', 'doc_count': 6},
#         {'key': 'Health', 'doc_count': 5},
#         {'key': 'Home Page', 'doc_count': 5},
#         {'key': 'Magazine', 'doc_count': 5},
#         {'key': 'Technology', 'doc_count': 5},
#         {'key': 'Podcasts', 'doc_count': 2}]}},
#      {'key_as_string': '2023-06-18T00:00:00.000Z',
#       'key': 1687046400000,
#       'doc_count': 52,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Corrections', 'doc_count': 10},
#         {'key': 'Times Insider', 'doc_count': 10},
#         {'key': 'Climate', 'doc_count': 6},
#         {'key': 'Theater', 'doc_count': 6},
#         {'key': 'Magazine', 'doc_count': 5},
#         {'key': 'Obituaries', 'doc_count': 5},
#         {'key': 'Science', 'doc_count': 5},
#         {'key': 'Food', 'doc_count': 3},
#         {'key': 'Podcasts', 'doc_count': 2}]}},
#      {'key_as_string': '2023-06-19T00:00:00.000Z',
#       'key': 1687132800000,
#       'doc_count': 107,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Travel', 'doc_count': 44},
#         {'key': 'Real Estate', 'doc_count': 10},
#         {'key': 'Science', 'doc_count': 10},
#         {'key': 'Food', 'doc_count': 8},
#         {'key': 'Corrections', 'doc_count': 5},
#         {'key': 'Home Page', 'doc_count': 5},
#         {'key': 'Magazine', 'doc_count': 5},
#         {'key': 'Technology', 'doc_count': 5},
#         {'key': 'Theater', 'doc_count': 5},
#         {'key': 'Times Insider', 'doc_count': 5},
#         {'key': 'Well', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-20T00:00:00.000Z',
#       'key': 1687219200000,
#       'doc_count': 125,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Food', 'doc_count': 20},
#         {'key': 'Travel', 'doc_count': 20},
#         {'key': 'Theater', 'doc_count': 15},
#         {'key': 'Climate', 'doc_count': 12},
#         {'key': 'Podcasts', 'doc_count': 12},
#         {'key': 'Corrections', 'doc_count': 10},
#         {'key': 'Briefing', 'doc_count': 6},
#         {'key': 'Health', 'doc_count': 5},
#         {'key': 'Magazine', 'doc_count': 5},
#         {'key': 'Real Estate', 'doc_count': 5},
#         {'key': 'Science', 'doc_count': 5},
#         {'key': 'The Learning Network', 'doc_count': 5},
#         {'key': 'Well', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-21T00:00:00.000Z',
#       'key': 1687305600000,
#       'doc_count': 182,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Real Estate', 'doc_count': 25},
#         {'key': 'Briefing', 'doc_count': 18},
#         {'key': 'Magazine', 'doc_count': 15},
#         {'key': 'Podcasts', 'doc_count': 15},
#         {'key': 'Science', 'doc_count': 15},
#         {'key': 'Theater', 'doc_count': 15},
#         {'key': 'Corrections', 'doc_count': 10},
#         {'key': 'Food', 'doc_count': 10},
#         {'key': 'The Upshot', 'doc_count': 10},
#         {'key': 'Well', 'doc_count': 10},
#         {'key': 'Climate', 'doc_count': 6},
#         {'key': 'Health', 'doc_count': 5},
#         {'key': 'Technology', 'doc_count': 5},
#         {'key': 'The Learning Network', 'doc_count': 5},
#         {'key': 'Times Insider', 'doc_count': 5},
#         {'key': 'Gameplay', 'doc_count': 4},
#         {'key': 'Movies', 'doc_count': 4},
#         {'key': 'En español', 'doc_count': 3},
#         {'key': 'Sports', 'doc_count': 2}]}},
#      {'key_as_string': '2023-06-22T00:00:00.000Z',
#       'key': 1687392000000,
#       'doc_count': 309,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Movies', 'doc_count': 36},
#         {'key': 'The Learning Network', 'doc_count': 25},
#         {'key': 'Briefing', 'doc_count': 24},
#         {'key': 'Real Estate', 'doc_count': 20},
#         {'key': 'Science', 'doc_count': 20},
#         {'key': 'Magazine', 'doc_count': 15},
#         {'key': 'Podcasts', 'doc_count': 15},
#         {'key': 'T Magazine', 'doc_count': 15},
#         {'key': 'Technology', 'doc_count': 15},
#         {'key': 'Theater', 'doc_count': 15},
#         {'key': 'Climate', 'doc_count': 12},
#         {'key': 'Gameplay', 'doc_count': 12},
#         {'key': 'Style', 'doc_count': 12},
#         {'key': 'Corrections', 'doc_count': 10},
#         {'key': 'Food', 'doc_count': 10},
#         {'key': 'Health', 'doc_count': 10},
#         {'key': 'Well', 'doc_count': 10},
#         {'key': 'Books', 'doc_count': 9},
#         {'key': 'Sports', 'doc_count': 8},
#         {'key': 'En español', 'doc_count': 6},
#         {'key': 'Home Page', 'doc_count': 5},
#         {'key': 'Travel', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-23T00:00:00.000Z',
#       'key': 1687478400000,
#       'doc_count': 490,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Style', 'doc_count': 39},
#         {'key': 'Books', 'doc_count': 34},
#         {'key': 'Sports', 'doc_count': 33},
#         {'key': 'Briefing', 'doc_count': 30},
#         {'key': 'Podcasts', 'doc_count': 30},
#         {'key': 'Arts', 'doc_count': 27},
#         {'key': 'Movies', 'doc_count': 25},
#         {'key': 'The Learning Network', 'doc_count': 25},
#         {'key': 'Theater', 'doc_count': 25},
#         {'key': 'En español', 'doc_count': 22},
#         {'key': 'Food', 'doc_count': 20},
#         {'key': 'Gameplay', 'doc_count': 20},
#         {'key': 'Travel', 'doc_count': 20},
#         {'key': 'Business', 'doc_count': 19},
#         {'key': 'Technology', 'doc_count': 15},
#         {'key': 'Well', 'doc_count': 15},
#         {'key': 'New York', 'doc_count': 14},
#         {'key': 'Climate', 'doc_count': 12},
#         {'key': 'Corrections', 'doc_count': 10},
#         {'key': 'Home Page', 'doc_count': 10},
#         {'key': 'Magazine', 'doc_count': 10},
#         {'key': 'T Magazine', 'doc_count': 10},
#         {'key': 'Health', 'doc_count': 5},
#         {'key': 'Real Estate', 'doc_count': 5},
#         {'key': 'Science', 'doc_count': 5},
#         {'key': 'Smarter Living', 'doc_count': 5},
#         {'key': 'Times Insider', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-24T00:00:00.000Z',
#       'key': 1687564800000,
#       'doc_count': 212,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Business', 'doc_count': 25},
#         {'key': 'En español', 'doc_count': 25},
#         {'key': 'Gameplay', 'doc_count': 20},
#         {'key': 'Books', 'doc_count': 18},
#         {'key': 'Climate', 'doc_count': 18},
#         {'key': 'Opinion', 'doc_count': 11},
#         {'key': 'Corrections', 'doc_count': 10},
#         {'key': 'Fashion', 'doc_count': 10},
#         {'key': 'Movies', 'doc_count': 10},
#         {'key': 'Science', 'doc_count': 10},
#         {'key': 'Sports', 'doc_count': 10},
#         {'key': 'Style', 'doc_count': 10},
#         {'key': 'Briefing', 'doc_count': 6},
#         {'key': 'Podcasts', 'doc_count': 5},
#         {'key': 'Real Estate', 'doc_count': 5},
#         {'key': 'The Upshot', 'doc_count': 5},
#         {'key': 'Times Insider', 'doc_count': 5},
#         {'key': 'Arts', 'doc_count': 4},
#         {'key': 'U.S.', 'doc_count': 3},
#         {'key': 'New York', 'doc_count': 2}]}},
#      {'key_as_string': '2023-06-25T00:00:00.000Z',
#       'key': 1687651200000,
#       'doc_count': 246,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'New York', 'doc_count': 22},
#         {'key': 'U.S.', 'doc_count': 22},
#         {'key': 'Opinion', 'doc_count': 21},
#         {'key': 'Books', 'doc_count': 18},
#         {'key': 'Gameplay', 'doc_count': 15},
#         {'key': 'Obituaries', 'doc_count': 15},
#         {'key': 'Style', 'doc_count': 15},
#         {'key': 'Arts', 'doc_count': 13},
#         {'key': 'Briefing', 'doc_count': 12},
#         {'key': 'Corrections', 'doc_count': 10},
#         {'key': 'En español', 'doc_count': 10},
#         {'key': 'Home Page', 'doc_count': 10},
#         {'key': 'Sports', 'doc_count': 10},
#         {'key': 'Business', 'doc_count': 6},
#         {'key': 'Climate', 'doc_count': 6},
#         {'key': 'World', 'doc_count': 6},
#         {'key': 'Food', 'doc_count': 5},
#         {'key': 'Magazine', 'doc_count': 5},
#         {'key': 'Movies', 'doc_count': 5},
#         {'key': 'Real Estate', 'doc_count': 5},
#         {'key': 'Science', 'doc_count': 5},
#         {'key': 'Technology', 'doc_count': 5},
#         {'key': 'Times Insider', 'doc_count': 5}]}},
#      {'key_as_string': '2023-06-26T00:00:00.000Z',
#       'key': 1687737600000,
#       'doc_count': 521,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'Arts', 'doc_count': 54},
#         {'key': 'New York', 'doc_count': 45},
#         {'key': 'World', 'doc_count': 45},
#         {'key': 'Opinion', 'doc_count': 42},
#         {'key': 'Business', 'doc_count': 38},
#         {'key': 'U.S.', 'doc_count': 29},
#         {'key': 'Books', 'doc_count': 21},
#         {'key': 'En español', 'doc_count': 20},
#         {'key': 'Gameplay', 'doc_count': 20},
#         {'key': 'Sports', 'doc_count': 20},
#         {'key': 'The Learning Network', 'doc_count': 20},
#         {'key': 'Briefing', 'doc_count': 18},
#         {'key': 'Real Estate', 'doc_count': 15},
#         {'key': 'Style', 'doc_count': 14},
#         {'key': 'Technology', 'doc_count': 14},
#         {'key': 'Food', 'doc_count': 13},
#         {'key': 'Theater', 'doc_count': 11},
#         {'key': 'Health', 'doc_count': 10},
#         {'key': 'Podcasts', 'doc_count': 10},
#         {'key': 'Science', 'doc_count': 10},
#         {'key': 'Well', 'doc_count': 10},
#         {'key': 'Movies', 'doc_count': 8},
#         {'key': 'Climate', 'doc_count': 6},
#         {'key': 'Corrections', 'doc_count': 5},
#         {'key': 'T Magazine', 'doc_count': 5},
#         {'key': 'The Upshot', 'doc_count': 5},
#         {'key': 'Travel', 'doc_count': 5},
#         {'key': 'Home Page', 'doc_count': 3},
#         {'key': 'Magazine', 'doc_count': 3},
#         {'key': 'Obituaries', 'doc_count': 2}]}},
#      {'key_as_string': '2023-06-27T00:00:00.000Z',
#       'key': 1687824000000,
#       'doc_count': 361,
#       'unique_section': {'doc_count_error_upper_bound': 0,
#        'sum_other_doc_count': 0,
#        'buckets': [{'key': 'World', 'doc_count': 49},
#         {'key': 'U.S.', 'doc_count': 46},
#         {'key': 'Business', 'doc_count': 32},
#         {'key': 'Opinion', 'doc_count': 26},
#         {'key': 'Arts', 'doc_count': 22},
#         {'key': 'Books', 'doc_count': 20},
#         {'key': 'New York', 'doc_count': 17},
#         {'key': 'Sports', 'doc_count': 17},
#         {'key': 'En español', 'doc_count': 14},
#         {'key': 'Movies', 'doc_count': 12},
#         {'key': 'Style', 'doc_count': 10},
#         {'key': 'Corrections', 'doc_count': 9},
#         {'key': 'Gameplay', 'doc_count': 9},
#         {'key': 'Podcasts', 'doc_count': 9},
#         {'key': 'Well', 'doc_count': 9},
#         {'key': 'Health', 'doc_count': 7},
#         {'key': 'The Upshot', 'doc_count': 7},
#         {'key': 'Briefing', 'doc_count': 6},
#         {'key': 'Food', 'doc_count': 6},
#         {'key': 'Magazine', 'doc_count': 6},
#         {'key': 'The Learning Network', 'doc_count': 6},
#         {'key': 'Travel', 'doc_count': 6},
#         {'key': 'Climate', 'doc_count': 5},
#         {'key': 'Real Estate', 'doc_count': 4},
#         {'key': 'Theater', 'doc_count': 4},
#         {'key': 'Times Insider', 'doc_count': 3}]}}]}}}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# articles published on a specific day
query_body = {
    "query": {
        "match": {
            "first_published_date": {
                "query": "2023-06-23"
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/3117681231.py:16: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 24,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 490, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'news',
#     '_id': 'NSjO-IgBq0sA4CElihZ8',
#     '_score': 1.0,
#     '_source': {'slug_name': '25JONI-PHOTO',
#      'section': 'Arts',
#      'subsection': 'Music',
#      'title': 'Joni Mitchell Finally Returned. Her Fans Were Waiting.',
#      'abstract': 'The crowd at the singer-songwriter’s first announced concert in more than two decades was intergenerational and grateful.',
#      'uri': 'nyt://article/34ef3e88-c979-5b35-b7a3-775cebd0a00b',
#      'url': 'https://www.nytimes.com/2023/06/23/arts/music/joni-mitchell-concert-photos.html',
#      'byline': 'By Lindsay Zoladz and Justin J Wee',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-23T17:00:33-04:00',
#      'created_date': '2023-06-23T17:00:33-04:00',
#      'published_date': '2023-06-23T17:00:33-04:00',
#      'first_published_date': '2023-06-23T17:00:33-04:00',
#      'material_type_facet': 'News',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': ['Folk Music', 'Pop and Rock Music'],
#      'org_facet': ['Gorge Amphitheater (George, Wash)'],
#      'per_facet': ['Swift, Taylor', 'Mitchell, Joni'],
#      'geo_facet': ['Washington (State)'],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25JONI-PHOTO-qbtm/25JONI-PHOTO-qbtm-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': ''},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25JONI-PHOTO-qbtm/25JONI-PHOTO-qbtm-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': ''},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25JONI-PHOTO-qbtm/25JONI-PHOTO-qbtm-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': ''},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25JONI-PHOTO-qbtm/25JONI-PHOTO-qbtm-articleInline.jpg',
#        'format': 'Normal',
#        'height': 152,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': ''}]}},
#    {'_index': 'news',
#     '_id': 'NijO-IgBq0sA4CElihZ8',
#     '_score': 1.0,
#     '_source': {'slug_name': '23like-water-review',
#      'section': 'Arts',
#      'subsection': 'Dance',
#      'title': 'Review: In ‘Like Water for Chocolate,’ Plot Overtakes Ballet',
#      'abstract': 'American Ballet Theater opened its summer season with Christopher Wheeldon’s new three-act ballet, inspired by a novel and film.',
#      'uri': 'nyt://article/670d9d46-78ce-5168-8319-0be30ee13983',
#      'url': 'https://www.nytimes.com/2023/06/23/arts/dance/like-water-for-chocolate-ballet-review.html',
#      'byline': 'By Gia Kourlas',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-23T14:12:28-04:00',
#      'created_date': '2023-06-23T14:12:28-04:00',
#      'published_date': '2023-06-23T14:12:28-04:00',
#      'first_published_date': '2023-06-23T14:12:28-04:00',
#      'material_type_facet': 'Review',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': ['Dancing'],
#      'org_facet': ['American Ballet Theater'],
#      'per_facet': ['Wheeldon, Christopher'],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/23like-water-review-twqm/23like-water-review-twqm-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'From left, Christine Shevchenko, Herman Cornejo and Cassandra Trenary in Christopher Wheeldon’s “Like Water for Chocolate” at American Ballet Theater.',
#        'copyright': 'Andrea Mohin/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/23like-water-review-twqm/23like-water-review-twqm-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'From left, Christine Shevchenko, Herman Cornejo and Cassandra Trenary in Christopher Wheeldon’s “Like Water for Chocolate” at American Ballet Theater.',
#        'copyright': 'Andrea Mohin/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/23like-water-review-twqm/23like-water-review-twqm-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'From left, Christine Shevchenko, Herman Cornejo and Cassandra Trenary in Christopher Wheeldon’s “Like Water for Chocolate” at American Ballet Theater.',
#        'copyright': 'Andrea Mohin/The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/23like-water-review-twqm/23like-water-review-twqm-articleInline.jpg',
#        'format': 'Normal',
#        'height': 126,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'From left, Christine Shevchenko, Herman Cornejo and Cassandra Trenary in Christopher Wheeldon’s “Like Water for Chocolate” at American Ballet Theater.',
#        'copyright': 'Andrea Mohin/The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'NyjO-IgBq0sA4CElihZ8',
#     '_score': 1.0,
#     '_source': {'slug_name': '23amplifier-web',
#      'section': 'Arts',
#      'subsection': 'Music',
#      'title': 'The Majesty of the Cure’s Live Show',
#      'abstract': 'Robert Smith’s band cast a spell on New York this week. Listen to a playlist that showcases the long-running group’s onstage power.',
#      'uri': 'nyt://article/c5995290-4a24-5d5d-82e3-dc03e53e7187',
#      'url': 'https://www.nytimes.com/2023/06/23/arts/music/amplifier-newsletter-the-cure-live.html',
#      'byline': '',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-23T14:20:41-04:00',
#      'created_date': '2023-06-23T14:00:03-04:00',
#      'published_date': '2023-06-23T14:00:03-04:00',
#      'first_published_date': '2023-06-23T14:00:03-04:00',
#      'material_type_facet': 'News',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': ['internal-sub-only-nl', 'Pop and Rock Music'],
#      'org_facet': ['Cure, The (Music Group)'],
#      'per_facet': ['Smith, Robert James (1959- )'],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/23amplifier-nl-wlzv/23amplifier-nl-wlzv-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Robert Smith onstage at Madison Square Garden on Thursday, during what’s become one of the year’s buzziest tours.',
#        'copyright': 'Nina Westervelt for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/23amplifier-nl-wlzv/23amplifier-nl-wlzv-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Robert Smith onstage at Madison Square Garden on Thursday, during what’s become one of the year’s buzziest tours.',
#        'copyright': 'Nina Westervelt for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/23amplifier-nl-wlzv/23amplifier-nl-wlzv-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Robert Smith onstage at Madison Square Garden on Thursday, during what’s become one of the year’s buzziest tours.',
#        'copyright': 'Nina Westervelt for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/23amplifier-nl-wlzv/23amplifier-nl-wlzv-articleInline.jpg',
#        'format': 'Normal',
#        'height': 254,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Robert Smith onstage at Madison Square Garden on Thursday, during what’s become one of the year’s buzziest tours.',
#        'copyright': 'Nina Westervelt for The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'OyjO-IgBq0sA4CElihZ8',
#     '_score': 1.0,
#     '_source': {'slug_name': '02virgo',
#      'section': 'Arts',
#      'subsection': 'Television',
#      'title': 'How ‘I’m a Virgo’ Pulled Off Old-School Movie Magic',
#      'abstract': 'The star Jharrel Jerome and senior members of the creative team discuss how they created the distinctive look of this ambitious new Amazon series.',
#      'uri': 'nyt://article/abe871f0-71e9-5f6e-89a3-2bf4309a7476',
#      'url': 'https://www.nytimes.com/2023/06/23/arts/television/im-a-virgo.html',
#      'byline': 'By Reggie Ugwu',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-23T10:00:12-04:00',
#      'created_date': '2023-06-23T10:00:12-04:00',
#      'published_date': '2023-06-23T10:00:12-04:00',
#      'first_published_date': '2023-06-23T10:00:12-04:00',
#      'material_type_facet': 'News',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': ['Television', 'Puppets'],
#      'org_facet': [],
#      'per_facet': ['Riley, Boots',
#       'Jerome, Jharrel (1997- )',
#       'Moynier, Eric',
#       'Winkless, Garth'],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/23virgo1-khwt/23virgo1-khwt-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '“Nothing was easy,” Jerome said of filming the effects-heavy series. “A scene that might normally have taken an hour-and-a-half would take three to four hours for us.”',
#        'copyright': 'Damien Maloney for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/23virgo1-khwt/23virgo1-khwt-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '“Nothing was easy,” Jerome said of filming the effects-heavy series. “A scene that might normally have taken an hour-and-a-half would take three to four hours for us.”',
#        'copyright': 'Damien Maloney for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/23virgo1-khwt/23virgo1-khwt-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '“Nothing was easy,” Jerome said of filming the effects-heavy series. “A scene that might normally have taken an hour-and-a-half would take three to four hours for us.”',
#        'copyright': 'Damien Maloney for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/multimedia/23virgo1-khwt/23virgo1-khwt-articleInline.jpg',
#        'format': 'Normal',
#        'height': 152,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '“Nothing was easy,” Jerome said of filming the effects-heavy series. “A scene that might normally have taken an hour-and-a-half would take three to four hours for us.”',
#        'copyright': 'Damien Maloney for The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'WSjO-IgBq0sA4CEl8BY9',
#     '_score': 1.0,
#     '_source': {'slug_name': '23podcast-article',
#      'section': 'Books',
#      'subsection': 'Book Review',
#      'title': 'Remembering Cormac McCarthy and Robert Gottlieb',
#      'abstract': 'Two giants of the literary world died last week. In this episode, the Book Review celebrates their lives.',
#      'uri': 'nyt://article/3d992180-b10b-53b0-a247-192e511b70e5',
#      'url': 'https://www.nytimes.com/2023/06/23/books/review/remembering-cormac-mccarthy-robert-gottlieb.html',
#      'byline': '',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-23T18:11:22-04:00',
#      'created_date': '2023-06-23T18:11:22-04:00',
#      'published_date': '2023-06-23T18:11:22-04:00',
#      'first_published_date': '2023-06-23T18:11:22-04:00',
#      'material_type_facet': 'News',
#      'kicker': '',
#      'subheadline': '',
#      'des_facet': ['Books and Literature'],
#      'org_facet': [],
#      'per_facet': [],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/24bookreview-Mccarthey-gvcm/24bookreview-Mccarthey-gvcm-thumbStandard-v4.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Photo Illustration by The New York Times. Photos by: Beowulf Sheehan/Beowulf Sheehan, via Associated Press; George Etheredge for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/24bookreview-Mccarthey-gvcm/24bookreview-Mccarthey-gvcm-mediumThreeByTwo210-v5.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Photo Illustration by The New York Times. Photos by: Beowulf Sheehan/Beowulf Sheehan, via Associated Press; George Etheredge for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/24bookreview-Mccarthey-gvcm/24bookreview-Mccarthey-gvcm-mediumThreeByTwo440-v5.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Photo Illustration by The New York Times. Photos by: Beowulf Sheehan/Beowulf Sheehan, via Associated Press; George Etheredge for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/24/multimedia/24bookreview-Mccarthey-gvcm/24bookreview-Mccarthey-gvcm-articleInline-v4.jpg',
#        'format': 'Normal',
#        'height': 107,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Photo Illustration by The New York Times. Photos by: Beowulf Sheehan/Beowulf Sheehan, via Associated Press; George Etheredge for The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'WijO-IgBq0sA4CEl8BY9',
#     '_score': 1.0,
#     '_source': {'slug_name': '14Calvo-Review',
#      'section': 'Books',
#      'subsection': 'Book Review',
#      'title': 'Can Plants Think?',
#      'abstract': 'In “Planta Sapiens,” Paco Calvo addresses our “plant blindness.”',
#      'uri': 'nyt://article/2ee094f0-0601-508d-a3ac-e28836f01baf',
#      'url': 'https://www.nytimes.com/2023/06/23/books/review/planta-sapiens-paco-calvo.html',
#      'byline': 'By Temple Grandin',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-23T15:00:11-04:00',
#      'created_date': '2023-06-23T15:00:12-04:00',
#      'published_date': '2023-06-23T15:00:12-04:00',
#      'first_published_date': '2023-06-23T15:00:12-04:00',
#      'material_type_facet': 'Review',
#      'kicker': 'Nonfiction',
#      'subheadline': '',
#      'des_facet': ['Books and Literature',
#       'Flowers and Plants',
#       'Trees and Shrubs',
#       'Nerves and Nervous System',
#       'Animal Behavior',
#       'Animal Cognition'],
#      'org_facet': [],
#      'per_facet': ['Calvo, Paco', 'Lawrence, Natalie (Author)'],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25Calvo/03Calvo-phzj-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Paco Calvo makes an argument for a plant’s ability to learn and retain information.',
#        'copyright': 'Poras Chaudhary for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25Calvo/03Calvo-phzj-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Paco Calvo makes an argument for a plant’s ability to learn and retain information.',
#        'copyright': 'Poras Chaudhary for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25Calvo/03Calvo-phzj-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Paco Calvo makes an argument for a plant’s ability to learn and retain information.',
#        'copyright': 'Poras Chaudhary for The New York Times'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25Calvo/03Calvo-phzj-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Paco Calvo makes an argument for a plant’s ability to learn and retain information.',
#        'copyright': 'Poras Chaudhary for The New York Times'}]}},
#    {'_index': 'news',
#     '_id': 'WyjO-IgBq0sA4CEl8BY9',
#     '_score': 1.0,
#     '_source': {'slug_name': 'new-paperbacks-proulx',
#      'section': 'Books',
#      'subsection': '',
#      'title': '6 New Paperbacks to Read This Week ',
#      'abstract': 'Selected paperbacks from the Book Review, including titles from Annie Proulx, Beth Macy and more. ',
#      'uri': 'nyt://interactive/36a5c3f3-7363-5521-b1eb-96428586ecf5',
#      'url': 'https://www.nytimes.com/interactive/2023/06/23/books/new-paperbacks-proulx.html',
#      'byline': 'By Shreya Chattopadhyay',
#      'item_type': 'Interactive',
#      'source': 'New York Times',
#      'updated_date': '2023-06-23T14:32:27-04:00',
#      'created_date': '2023-06-23T13:52:02-04:00',
#      'published_date': '2023-06-23T13:52:02-04:00',
#      'first_published_date': '2023-06-23T13:52:02-04:00',
#      'material_type_facet': 'Interactive Feature',
#      'kicker': 'Paperback Row',
#      'subheadline': '',
#      'des_facet': ['Books and Literature', 'National Book Awards'],
#      'org_facet': ['Bookforum (Magazine)'],
#      'per_facet': ['Macy, Beth', 'Proulx, Annie'],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/23/books/23PAPERBACK-BURST-PROMO/23PAPERBACK-BURST-PROMO-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': ''},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/books/23PAPERBACK-BURST-PROMO/23PAPERBACK-BURST-PROMO-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': ''},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/books/23PAPERBACK-BURST-PROMO/23PAPERBACK-BURST-PROMO-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': ''},
#       {'url': 'https://static01.nyt.com/images/2023/06/23/books/23PAPERBACK-BURST-PROMO/23PAPERBACK-BURST-PROMO-articleInline.jpg',
#        'format': 'Normal',
#        'height': 127,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': ''}]}},
#    {'_index': 'news',
#     '_id': 'XCjO-IgBq0sA4CEl8BY9',
#     '_score': 1.0,
#     '_source': {'slug_name': '23ROMANCE-June',
#      'section': 'Books',
#      'subsection': 'Book Review',
#      'title': 'Three Summery, Swoonworthy New Romance Novels',
#      'abstract': 'Want to dip your brain into a jar of serotonin?',
#      'uri': 'nyt://article/2b9efb30-842c-5de5-a0c9-2b7168c76cc7',
#      'url': 'https://www.nytimes.com/2023/06/23/books/review/new-romance-books.html',
#      'byline': 'By Olivia Waite',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-23T10:59:24-04:00',
#      'created_date': '2023-06-23T10:59:24-04:00',
#      'published_date': '2023-06-23T10:59:24-04:00',
#      'first_published_date': '2023-06-23T10:59:24-04:00',
#      'material_type_facet': 'News',
#      'kicker': 'Romance',
#      'subheadline': '',
#      'des_facet': ['Books and Literature', 'genre-books-romance'],
#      'org_facet': [],
#      'per_facet': ['Sebastian, Cat', 'Jalaluddin, Uzma', 'Cervantes, J C'],
#      'geo_facet': [],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/25/books/review/22ROMANCE-JUNE/22ROMANCE-JUNE-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Michela Buttignol'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/books/review/22ROMANCE-JUNE/22ROMANCE-JUNE-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Michela Buttignol'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/books/review/22ROMANCE-JUNE/22ROMANCE-JUNE-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Michela Buttignol'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/books/review/22ROMANCE-JUNE/22ROMANCE-JUNE-articleInline.jpg',
#        'format': 'Normal',
#        'height': 231,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': '',
#        'copyright': 'Michela Buttignol'}]}},
#    {'_index': 'news',
#     '_id': 'XSjO-IgBq0sA4CEl8BY9',
#     '_score': 1.0,
#     '_source': {'slug_name': '23upclose_loisaida',
#      'section': 'Books',
#      'subsection': '',
#      'title': 'In ‘Loisaida,’ Photos of a Bygone New York',
#      'abstract': 'Between 1984 and 1990, Tria Giovan captured everyday life on the Lower East Side.',
#      'uri': 'nyt://article/3f9fd7f0-69f4-5279-b3b3-0cda902f20ad',
#      'url': 'https://www.nytimes.com/2023/06/23/books/loisaida-tria-giovan.html',
#      'byline': 'By Lauren Christensen',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-23T10:47:14-04:00',
#      'created_date': '2023-06-23T05:01:42-04:00',
#      'published_date': '2023-06-23T05:01:42-04:00',
#      'first_published_date': '2023-06-23T05:01:42-04:00',
#      'material_type_facet': 'News',
#      'kicker': 'Up Close',
#      'subheadline': '',
#      'des_facet': ['Photography',
#       'Books and Literature',
#       'Nineteen Hundred Eighties'],
#      'org_facet': [],
#      'per_facet': ['Giovan, Tria'],
#      'geo_facet': ['Lower East Side (Manhattan, NY)'],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25BackPage_Loisada-07-pfkj/25BackPage_Loisada-07-pfkj-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Neighbors gather on a fire escape on Stanton Street, 1990.',
#        'copyright': 'Tria Giovan'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25BackPage_Loisada-07-pfkj/25BackPage_Loisada-07-pfkj-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Neighbors gather on a fire escape on Stanton Street, 1990.',
#        'copyright': 'Tria Giovan'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25BackPage_Loisada-07-pfkj/25BackPage_Loisada-07-pfkj-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Neighbors gather on a fire escape on Stanton Street, 1990.',
#        'copyright': 'Tria Giovan'},
#       {'url': 'https://static01.nyt.com/images/2023/06/25/multimedia/25BackPage_Loisada-07-pfkj/25BackPage_Loisada-07-pfkj-articleInline.jpg',
#        'format': 'Normal',
#        'height': 285,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'Neighbors gather on a fire escape on Stanton Street, 1990.',
#        'copyright': 'Tria Giovan'}]}},
#    {'_index': 'news',
#     '_id': 'XyjO-IgBq0sA4CEl8BY9',
#     '_score': 1.0,
#     '_source': {'slug_name': '23Storey-Review',
#      'section': 'Books',
#      'subsection': 'Book Review',
#      'title': 'Where Kennedys Sail and Play Football, Others Cook and Clean',
#      'abstract': 'In “White House by the Sea,” Kate Storey gives readers a comprehensive tour of the summer home beloved by a certain political clan.',
#      'uri': 'nyt://article/71b5e082-2a2a-5447-9b9c-cf5355a6706c',
#      'url': 'https://www.nytimes.com/2023/06/23/books/review/white-house-by-the-sea-kate-storey.html',
#      'byline': 'By Louis Bayard',
#      'item_type': 'Article',
#      'source': 'New York Times',
#      'updated_date': '2023-06-23T05:00:39-04:00',
#      'created_date': '2023-06-23T05:00:39-04:00',
#      'published_date': '2023-06-23T05:00:39-04:00',
#      'first_published_date': '2023-06-23T05:00:39-04:00',
#      'material_type_facet': 'Review',
#      'kicker': 'Nonfiction',
#      'subheadline': '',
#      'des_facet': ['Books and Literature',
#       'Content Type: Personal Profile',
#       'United States Politics and Government',
#       'Historic Buildings and Sites'],
#      'org_facet': [],
#      'per_facet': ['Kennedy Family', 'Storey, Kate (Journalist)'],
#      'geo_facet': ['Hyannis (Mass)'],
#      'related_urls': [],
#      'multimedia': [{'url': 'https://static01.nyt.com/images/2023/06/27/books/27Storey-promo/27Storey-promo-thumbStandard-v2.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'In 1963, President John F. Kennedy visited Hyannis Port and Squaw Island, Mass., with his family. This is an image taken from silent footage of the weekend. \n\n',
#        'copyright': ''},
#       {'url': 'https://static01.nyt.com/images/2023/06/27/books/27Storey-promo/27Storey-promo-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'In 1963, President John F. Kennedy visited Hyannis Port and Squaw Island, Mass., with his family. This is an image taken from silent footage of the weekend. \n\n',
#        'copyright': ''},
#       {'url': 'https://static01.nyt.com/images/2023/06/27/books/27Storey-promo/27Storey-promo-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'In 1963, President John F. Kennedy visited Hyannis Port and Squaw Island, Mass., with his family. This is an image taken from silent footage of the weekend. \n\n',
#        'copyright': ''},
#       {'url': 'https://static01.nyt.com/images/2023/06/27/books/27Storey-promo/Screen-Shot-2023-06-06-at-8-articleInline.jpg',
#        'format': 'Normal',
#        'height': 143,
#        'width': 190,
#        'type': 'image',
#        'subtype': 'photo',
#        'caption': 'In 1963, President John F. Kennedy visited Hyannis Port and Squaw Island, Mass., with his family. This is an image taken from silent footage of the weekend. \n\n',
#        'copyright': ''}]}}]}}

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(hosts="http://localhost:9200")

# number of articles published on a specific day per section
query_body = {
    "size": 0,
    "aggs": {
        "day_based_filter": {
            "filter": {
                "match": {
                    "first_published_date": {
                        "query": "2023-06-23"
                    }
                }
            },
            "aggs": {
                "unique_section": {
                    "terms": {
                        "field": "section",
                        "size": 500
                    }
                }
            }
        }
    }
}

result = es.search(index="news", body=query_body)
result.body
# Out:
# /var/folders/rs/p_w2q_r55xq_y1k4j_wfd0l00000gn/T/ipykernel_97197/3643086070.py:29: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   result = es.search(index="news", body=query_body)
# {'took': 6,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 4680, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'day_based_filter': {'meta': {},
#    'doc_count': 490,
#    'unique_section': {'doc_count_error_upper_bound': 0,
#     'sum_other_doc_count': 0,
#     'buckets': [{'key': 'Style', 'doc_count': 39},
#      {'key': 'Books', 'doc_count': 34},
#      {'key': 'Sports', 'doc_count': 33},
#      {'key': 'Briefing', 'doc_count': 30},
#      {'key': 'Podcasts', 'doc_count': 30},
#      {'key': 'Arts', 'doc_count': 27},
#      {'key': 'Movies', 'doc_count': 25},
#      {'key': 'The Learning Network', 'doc_count': 25},
#      {'key': 'Theater', 'doc_count': 25},
#      {'key': 'En español', 'doc_count': 22},
#      {'key': 'Food', 'doc_count': 20},
#      {'key': 'Gameplay', 'doc_count': 20},
#      {'key': 'Travel', 'doc_count': 20},
#      {'key': 'Business', 'doc_count': 19},
#      {'key': 'Technology', 'doc_count': 15},
#      {'key': 'Well', 'doc_count': 15},
#      {'key': 'New York', 'doc_count': 14},
#      {'key': 'Climate', 'doc_count': 12},
#      {'key': 'Corrections', 'doc_count': 10},
#      {'key': 'Home Page', 'doc_count': 10},
#      {'key': 'Magazine', 'doc_count': 10},
#      {'key': 'T Magazine', 'doc_count': 10},
#      {'key': 'Health', 'doc_count': 5},
#      {'key': 'Real Estate', 'doc_count': 5},
#      {'key': 'Science', 'doc_count': 5},
#      {'key': 'Smarter Living', 'doc_count': 5},
#      {'key': 'Times Insider', 'doc_count': 5}]}}}}
